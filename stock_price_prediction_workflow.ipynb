# %% [markdown]
# This notebook replicates the Airflow DAG and its tasks for stock price prediction using a Random Forest model.

# %%
# !pip install \
    apache-airflow apache-airflow-providers-google \
    pandas numpy scikit-learn joblib holidays \
    pandas-gbq google-auth numpy

from datetime import datetime, timedelta, date
import pandas as pd
import numpy as np
from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error, r2_score
import joblib
import os
import logging
import holidays

from airflow import DAG
from airflow.operators.python import PythonOperator
from airflow.operators.dummy import DummyOperator
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: apache-airflow in /home/jtsarmento/.local/lib/python3.10/site-packages (3.0.0)
# Requirement already satisfied: apache-airflow-providers-google in /home/jtsarmento/.local/lib/python3.10/site-packages (15.1.0)
# Requirement already satisfied: pandas in /home/jtsarmento/.local/lib/python3.10/site-packages (2.1.4)
# Requirement already satisfied: numpy in /home/jtsarmento/.local/lib/python3.10/site-packages (2.2.5)
# Requirement already satisfied: scikit-learn in /home/jtsarmento/.local/lib/python3.10/site-packages (1.6.1)
# Requirement already satisfied: joblib in /home/jtsarmento/.local/lib/python3.10/site-packages (1.4.2)
# Requirement already satisfied: holidays in /home/jtsarmento/.local/lib/python3.10/site-packages (0.71)
# Requirement already satisfied: pandas-gbq in /home/jtsarmento/.local/lib/python3.10/site-packages (0.28.0)
# Requirement already satisfied: google-auth in /home/jtsarmento/.local/lib/python3.10/site-packages (2.37.0)
# Requirement already satisfied: apache-airflow-task-sdk<1.1.0,>=1.0.0 in /home/jtsarmento/.local/lib/python3.10/site-packages (from apache-airflow) (1.0.0)
# Requirement already satisfied: apache-airflow-core==3.0.0 in /home/jtsarmento/.local/lib/python3.10/site-packages (from apache-airflow) (3.0.0)
# Requirement already satisfied: importlib-metadata>=6.5 in /home/jtsarmento/.local/lib/python3.10/site-packages (from apache-airflow-core==3.0.0->apache-airflow) (6.11.0)
# Requirement already satisfied: deprecated>=1.2.13 in /home/jtsarmento/.local/lib/python3.10/site-packages (from apache-airflow-core==3.0.0->apache-airflow) (1.2.18)
# Requirement already satisfied: pluggy>=1.5.0 in /home/jtsarmento/.local/lib/python3.10/site-packages (from apache-airflow-core==3.0.0->apache-airflow) (1.5.0)
# Requirement already satisfied: itsdangerous>=2.0 in /home/jtsarmento/.local/lib/python3.10/site-packages (from apache-airflow-core==3.0.0->apache-airflow) (2.2.0)
# Requirement already satisfied: apache-airflow-providers-standard>=0.4.0 in /home/jtsarmento/.local/lib/python3.10/site-packages (from apache-airflow-core==3.0.0->apache-airflow) (1.0.0)
# Requirement already satisfied: requests<3,>=2.31.0 in /home/jtsarmento/.local/lib/python3.10/site-packages (from apache-airflow-core==3.0.0->apache-airflow) (2.31.0)
# Requirement already satisfied: pendulum<4.0,>=2.1.2 in /home/jtsarmento/.local/lib/python3.10/site-packages (from apache-airflow-core==3.0.0->apache-airflow) (3.1.0)
# Requirement already satisfied: a2wsgi>=1.10.8 in /home/jtsarmento/.local/lib/python3.10/site-packages (from apache-airflow-core==3.0.0->apache-airflow) (1.10.8)
# Requirement already satisfied: sqlalchemy-utils>=0.41.2 in /home/jtsarmento/.local/lib/python3.10/site-packages (from apache-airflow-core==3.0.0->apache-airflow) (0.41.2)
# Requirement already satisfied: python-dateutil>=2.7.0 in /home/jtsarmento/.local/lib/python3.10/site-packages (from apache-airflow-core==3.0.0->apache-airflow) (2.8.2)
# Requirement already satisfied: flask>=2.1.1 in /home/jtsarmento/.local/lib/python3.10/site-packages (from apache-airflow-core==3.0.0->apache-airflow) (3.0.2)
# Requirement already satisfied: gunicorn>=20.1.0 in /home/jtsarmento/.local/lib/python3.10/site-packages (from apache-airflow-core==3.0.0->apache-airflow) (21.2.0)
# Requirement already satisfied: opentelemetry-api>=1.24.0 in /home/jtsarmento/.local/lib/python3.10/site-packages (from apache-airflow-core==3.0.0->apache-airflow) (1.32.1)
# Requirement already satisfied: argcomplete>=1.10 in /home/jtsarmento/.local/lib/python3.10/site-packages (from apache-airflow-core==3.0.0->apache-airflow) (3.6.2)
# Requirement already satisfied: lockfile>=0.12.2 in /usr/lib/python3/dist-packages (from apache-airflow-core==3.0.0->apache-airflow) (0.12.2)
# Requirement already satisfied: apache-airflow-providers-common-io>=1.5.3 in /home/jtsarmento/.local/lib/python3.10/site-packages (from apache-airflow-core==3.0.0->apache-airflow) (1.5.4)
# Requirement already satisfied: cron-descriptor>=1.2.24 in /home/jtsarmento/.local/lib/python3.10/site-packages (from apache-airflow-core==3.0.0->apache-airflow) (1.4.5)
# Requirement already satisfied: alembic<2.0,>=1.13.1 in /home/jtsarmento/.local/lib/python3.10/site-packages (from apache-airflow-core==3.0.0->apache-airflow) (1.15.2)
# Requirement already satisfied: cadwyn>=5.2.1 in /home/jtsarmento/.local/lib/python3.10/site-packages (from apache-airflow-core==3.0.0->apache-airflow) (5.3.3)
# Requirement already satisfied: cryptography>=41.0.0 in /home/jtsarmento/.local/lib/python3.10/site-packages (from apache-airflow-core==3.0.0->apache-airflow) (44.0.2)
# Requirement already satisfied: lazy-object-proxy>=1.2.0 in /home/jtsarmento/.local/lib/python3.10/site-packages (from apache-airflow-core==3.0.0->apache-airflow) (1.11.0)
# Requirement already satisfied: python-slugify>=5.0 in /home/jtsarmento/.local/lib/python3.10/site-packages (from apache-airflow-core==3.0.0->apache-airflow) (8.0.4)
# Requirement already satisfied: colorlog>=6.8.2 in /home/jtsarmento/.local/lib/python3.10/site-packages (from apache-airflow-core==3.0.0->apache-airflow) (6.9.0)
# Requirement already satisfied: libcst>=1.1.0 in /home/jtsarmento/.local/lib/python3.10/site-packages (from apache-airflow-core==3.0.0->apache-airflow) (1.7.0)
# Requirement already satisfied: jinja2>=3.1.5 in /home/jtsarmento/.local/lib/python3.10/site-packages (from apache-airflow-core==3.0.0->apache-airflow) (3.1.6)
# Requirement already satisfied: croniter>=2.0.2 in /home/jtsarmento/.local/lib/python3.10/site-packages (from apache-airflow-core==3.0.0->apache-airflow) (6.0.0)
# Requirement already satisfied: uuid6>=2024.7.10 in /home/jtsarmento/.local/lib/python3.10/site-packages (from apache-airflow-core==3.0.0->apache-airflow) (2024.7.10)
# Requirement already satisfied: rich-argparse>=1.0.0 in /home/jtsarmento/.local/lib/python3.10/site-packages (from apache-airflow-core==3.0.0->apache-airflow) (1.7.0)
# Requirement already satisfied: sqlalchemy<2.0,>=1.4.49 in /home/jtsarmento/.local/lib/python3.10/site-packages (from apache-airflow-core==3.0.0->apache-airflow) (1.4.54)
# Requirement already satisfied: opentelemetry-exporter-otlp>=1.24.0 in /home/jtsarmento/.local/lib/python3.10/site-packages (from apache-airflow-core==3.0.0->apache-airflow) (1.32.1)
# Requirement already satisfied: httpx>=0.25.0 in /home/jtsarmento/.local/lib/python3.10/site-packages (from apache-airflow-core==3.0.0->apache-airflow) (0.28.1)
# Requirement already satisfied: dill>=0.2.2 in /home/jtsarmento/.local/lib/python3.10/site-packages (from apache-airflow-core==3.0.0->apache-airflow) (0.4.0)
# Requirement already satisfied: apache-airflow-providers-common-sql>=1.25.0 in /home/jtsarmento/.local/lib/python3.10/site-packages (from apache-airflow-core==3.0.0->apache-airflow) (1.26.0)
# Requirement already satisfied: methodtools>=0.4.7 in /home/jtsarmento/.local/lib/python3.10/site-packages (from apache-airflow-core==3.0.0->apache-airflow) (0.4.7)
# Requirement already satisfied: gitpython>=3.1.40 in /home/jtsarmento/.local/lib/python3.10/site-packages (from apache-airflow-core==3.0.0->apache-airflow) (3.1.44)
# Requirement already satisfied: tabulate>=0.9.0 in /home/jtsarmento/.local/lib/python3.10/site-packages (from apache-airflow-core==3.0.0->apache-airflow) (0.9.0)
# Requirement already satisfied: pydantic>=2.11.0 in /home/jtsarmento/.local/lib/python3.10/site-packages (from apache-airflow-core==3.0.0->apache-airflow) (2.11.3)
# Requirement already satisfied: sqlalchemy-jsonfield>=1.0 in /home/jtsarmento/.local/lib/python3.10/site-packages (from apache-airflow-core==3.0.0->apache-airflow) (1.0.2)
# Requirement already satisfied: svcs>=25.1.0 in /home/jtsarmento/.local/lib/python3.10/site-packages (from apache-airflow-core==3.0.0->apache-airflow) (25.1.0)
# Requirement already satisfied: universal-pathlib!=0.2.4,>=0.2.2 in /home/jtsarmento/.local/lib/python3.10/site-packages (from apache-airflow-core==3.0.0->apache-airflow) (0.2.6)
# Requirement already satisfied: apache-airflow-providers-smtp>=2.0.2 in /home/jtsarmento/.local/lib/python3.10/site-packages (from apache-airflow-core==3.0.0->apache-airflow) (2.0.3)
# Requirement already satisfied: aiosqlite>=0.20.0 in /home/jtsarmento/.local/lib/python3.10/site-packages (from apache-airflow-core==3.0.0->apache-airflow) (0.21.0)
# Requirement already satisfied: pathspec>=0.9.0 in /home/jtsarmento/.local/lib/python3.10/site-packages (from apache-airflow-core==3.0.0->apache-airflow) (0.10.1)
# Requirement already satisfied: psutil>=5.8.0 in /home/jtsarmento/.local/lib/python3.10/site-packages (from apache-airflow-core==3.0.0->apache-airflow) (6.1.1)
# Requirement already satisfied: pyjwt>=2.10.0 in /home/jtsarmento/.local/lib/python3.10/site-packages (from apache-airflow-core==3.0.0->apache-airflow) (2.10.1)
# Requirement already satisfied: apache-airflow-providers-common-compat>=1.6.0 in /home/jtsarmento/.local/lib/python3.10/site-packages (from apache-airflow-core==3.0.0->apache-airflow) (1.6.0)
# Requirement already satisfied: jsonschema>=4.19.1 in /home/jtsarmento/.local/lib/python3.10/site-packages (from apache-airflow-core==3.0.0->apache-airflow) (4.23.0)
# Requirement already satisfied: attrs!=25.2.0,>=22.1.0 in /home/jtsarmento/.local/lib/python3.10/site-packages (from apache-airflow-core==3.0.0->apache-airflow) (24.2.0)
# Requirement already satisfied: linkify-it-py>=2.0.0 in /home/jtsarmento/.local/lib/python3.10/site-packages (from apache-airflow-core==3.0.0->apache-airflow) (2.0.3)
# Requirement already satisfied: packaging>=23.2 in /home/jtsarmento/.local/lib/python3.10/site-packages (from apache-airflow-core==3.0.0->apache-airflow) (25.0)
# Requirement already satisfied: pygments!=2.19.0,>=2.0.1 in /home/jtsarmento/.local/lib/python3.10/site-packages (from apache-airflow-core==3.0.0->apache-airflow) (2.19.1)
# Requirement already satisfied: fastapi[standard]!=0.115.10,>=0.115.0 in /home/jtsarmento/.local/lib/python3.10/site-packages (from apache-airflow-core==3.0.0->apache-airflow) (0.115.12)
# Requirement already satisfied: python-daemon>=3.0.0 in /home/jtsarmento/.local/lib/python3.10/site-packages (from apache-airflow-core==3.0.0->apache-airflow) (3.1.2)
# Requirement already satisfied: setproctitle>=1.3.3 in /home/jtsarmento/.local/lib/python3.10/site-packages (from apache-airflow-core==3.0.0->apache-airflow) (1.3.5)
# Requirement already satisfied: asgiref>=2.3.0 in /home/jtsarmento/.local/lib/python3.10/site-packages (from apache-airflow-core==3.0.0->apache-airflow) (3.7.2)
# Requirement already satisfied: tenacity!=8.2.0,>=8.0.0 in /home/jtsarmento/.local/lib/python3.10/site-packages (from apache-airflow-core==3.0.0->apache-airflow) (9.1.2)
# Requirement already satisfied: termcolor>=3.0.0 in /home/jtsarmento/.local/lib/python3.10/site-packages (from apache-airflow-core==3.0.0->apache-airflow) (3.0.1)
# Requirement already satisfied: rich>=13.6.0 in /home/jtsarmento/.local/lib/python3.10/site-packages (from apache-airflow-core==3.0.0->apache-airflow) (14.0.0)
# Requirement already satisfied: google-cloud-spanner!=3.49.0,>=3.11.1 in /home/jtsarmento/.local/lib/python3.10/site-packages (from apache-airflow-providers-google) (3.53.0)
# Requirement already satisfied: immutabledict>=4.2.0 in /home/jtsarmento/.local/lib/python3.10/site-packages (from apache-airflow-providers-google) (4.2.1)
# Requirement already satisfied: google-auth-httplib2>=0.0.1 in /home/jtsarmento/.local/lib/python3.10/site-packages (from apache-airflow-providers-google) (0.2.0)
# Requirement already satisfied: google-cloud-dataplex>=2.6.0 in /home/jtsarmento/.local/lib/python3.10/site-packages (from apache-airflow-providers-google) (2.10.1)
# Requirement already satisfied: google-cloud-language>=2.9.0 in /home/jtsarmento/.local/lib/python3.10/site-packages (from apache-airflow-providers-google) (2.17.1)
# Requirement already satisfied: google-cloud-managedkafka>=0.1.6 in /home/jtsarmento/.local/lib/python3.10/site-packages (from apache-airflow-providers-google) (0.1.9)
# Requirement already satisfied: google-cloud-run>=0.10.0 in /home/jtsarmento/.local/lib/python3.10/site-packages (from apache-airflow-providers-google) (0.10.17)
# Requirement already satisfied: google-cloud-bigquery!=3.21.*,!=3.22.0,!=3.23.*,>=3.4.0 in /home/jtsarmento/.local/lib/python3.10/site-packages (from apache-airflow-providers-google) (3.31.0)
# Requirement already satisfied: google-cloud-dataproc>=5.12.0 in /home/jtsarmento/.local/lib/python3.10/site-packages (from apache-airflow-providers-google) (5.18.1)
# Requirement already satisfied: google-cloud-pubsub>=2.21.3 in /home/jtsarmento/.local/lib/python3.10/site-packages (from apache-airflow-providers-google) (2.29.0)
# Requirement already satisfied: google-cloud-dlp>=3.12.0 in /home/jtsarmento/.local/lib/python3.10/site-packages (from apache-airflow-providers-google) (3.29.0)
# Requirement already satisfied: google-cloud-monitoring>=2.18.0 in /home/jtsarmento/.local/lib/python3.10/site-packages (from apache-airflow-providers-google) (2.27.1)
# Requirement already satisfied: proto-plus>=1.19.6 in /home/jtsarmento/.local/lib/python3.10/site-packages (from apache-airflow-providers-google) (1.25.0)
# Requirement already satisfied: google-cloud-secret-manager>=2.16.0 in /home/jtsarmento/.local/lib/python3.10/site-packages (from apache-airflow-providers-google) (2.23.3)
# Requirement already satisfied: looker-sdk!=24.18.0,>=22.4.0 in /home/jtsarmento/.local/lib/python3.10/site-packages (from apache-airflow-providers-google) (25.4.0)
# Requirement already satisfied: google-cloud-alloydb>=0.4.0 in /home/jtsarmento/.local/lib/python3.10/site-packages (from apache-airflow-providers-google) (0.4.5)
# Requirement already satisfied: google-api-core!=2.16.0,!=2.18.0,>=2.11.0 in /home/jtsarmento/.local/lib/python3.10/site-packages (from apache-airflow-providers-google) (2.24.0)
# Requirement already satisfied: google-cloud-memcache>=1.7.0 in /home/jtsarmento/.local/lib/python3.10/site-packages (from apache-airflow-providers-google) (1.12.1)
# Requirement already satisfied: google-cloud-translate>=3.16.0 in /home/jtsarmento/.local/lib/python3.10/site-packages (from apache-airflow-providers-google) (3.20.2)
# Requirement already satisfied: google-ads>=26.0.0 in /home/jtsarmento/.local/lib/python3.10/site-packages (from apache-airflow-providers-google) (26.1.0)
# Requirement already satisfied: google-cloud-os-login>=2.9.1 in /home/jtsarmento/.local/lib/python3.10/site-packages (from apache-airflow-providers-google) (2.17.1)
# Requirement already satisfied: google-cloud-redis>=2.12.0 in /home/jtsarmento/.local/lib/python3.10/site-packages (from apache-airflow-providers-google) (2.18.1)
# Requirement already satisfied: google-cloud-tasks>=2.13.0 in /home/jtsarmento/.local/lib/python3.10/site-packages (from apache-airflow-providers-google) (2.19.2)
# Requirement already satisfied: google-cloud-storage-transfer>=1.4.1 in /home/jtsarmento/.local/lib/python3.10/site-packages (from apache-airflow-providers-google) (1.16.1)
# Requirement already satisfied: google-cloud-datacatalog>=3.23.0 in /home/jtsarmento/.local/lib/python3.10/site-packages (from apache-airflow-providers-google) (3.27.0)
# Requirement already satisfied: google-cloud-videointelligence>=2.11.0 in /home/jtsarmento/.local/lib/python3.10/site-packages (from apache-airflow-providers-google) (2.16.1)
# Requirement already satisfied: google-cloud-aiplatform[evaluation]>=1.73.0 in /home/jtsarmento/.local/lib/python3.10/site-packages (from apache-airflow-providers-google) (1.90.0)
# Requirement already satisfied: google-analytics-admin>=0.9.0 in /home/jtsarmento/.local/lib/python3.10/site-packages (from apache-airflow-providers-google) (0.24.0)
# Requirement already satisfied: gcloud-aio-auth>=5.2.0 in /home/jtsarmento/.local/lib/python3.10/site-packages (from apache-airflow-providers-google) (5.4.1)
# Requirement already satisfied: gcloud-aio-bigquery>=6.1.2 in /home/jtsarmento/.local/lib/python3.10/site-packages (from apache-airflow-providers-google) (7.1.0)
# Requirement already satisfied: google-cloud-texttospeech>=2.14.1 in /home/jtsarmento/.local/lib/python3.10/site-packages (from apache-airflow-providers-google) (2.26.0)
# Requirement already satisfied: google-cloud-vision>=3.4.0 in /home/jtsarmento/.local/lib/python3.10/site-packages (from apache-airflow-providers-google) (3.10.1)
# Requirement already satisfied: google-cloud-bigtable>=2.17.0 in /home/jtsarmento/.local/lib/python3.10/site-packages (from apache-airflow-providers-google) (2.30.1)
# Requirement already satisfied: grpcio-gcp>=0.2.2 in /home/jtsarmento/.local/lib/python3.10/site-packages (from apache-airflow-providers-google) (0.2.2)
# Requirement already satisfied: google-api-python-client>=2.0.2 in /home/jtsarmento/.local/lib/python3.10/site-packages (from apache-airflow-providers-google) (2.156.0)
# Requirement already satisfied: google-cloud-dataproc-metastore>=1.12.0 in /home/jtsarmento/.local/lib/python3.10/site-packages (from apache-airflow-providers-google) (1.18.2)
# Requirement already satisfied: google-cloud-kms>=2.15.0 in /home/jtsarmento/.local/lib/python3.10/site-packages (from apache-airflow-providers-google) (3.4.1)
# Requirement already satisfied: google-cloud-workflows>=1.10.0 in /home/jtsarmento/.local/lib/python3.10/site-packages (from apache-airflow-providers-google) (1.18.1)
# Requirement already satisfied: google-cloud-compute>=1.10.0 in /home/jtsarmento/.local/lib/python3.10/site-packages (from apache-airflow-providers-google) (1.30.0)
# Requirement already satisfied: PyOpenSSL>=23.0.0 in /home/jtsarmento/.local/lib/python3.10/site-packages (from apache-airflow-providers-google) (25.0.0)
# Requirement already satisfied: google-cloud-container>=2.52.0 in /home/jtsarmento/.local/lib/python3.10/site-packages (from apache-airflow-providers-google) (2.56.1)
# Requirement already satisfied: google-cloud-build>=3.31.0 in /home/jtsarmento/.local/lib/python3.10/site-packages (from apache-airflow-providers-google) (3.31.1)
# Requirement already satisfied: google-cloud-automl>=2.12.0 in /home/jtsarmento/.local/lib/python3.10/site-packages (from apache-airflow-providers-google) (2.16.3)
# Requirement already satisfied: pyarrow>=14.0.1 in /home/jtsarmento/.local/lib/python3.10/site-packages (from apache-airflow-providers-google) (19.0.1)
# Requirement already satisfied: google-cloud-logging>=3.5.0 in /home/jtsarmento/.local/lib/python3.10/site-packages (from apache-airflow-providers-google) (3.12.1)
# Requirement already satisfied: gcsfs>=2023.10.0 in /home/jtsarmento/.local/lib/python3.10/site-packages (from apache-airflow-providers-google) (2025.3.2)
# Requirement already satisfied: google-cloud-bigquery-datatransfer>=3.13.0 in /home/jtsarmento/.local/lib/python3.10/site-packages (from apache-airflow-providers-google) (3.19.1)
# Requirement already satisfied: google-cloud-storage>=2.7.0 in /home/jtsarmento/.local/lib/python3.10/site-packages (from apache-airflow-providers-google) (2.19.0)
# Requirement already satisfied: google-cloud-dataform>=0.5.0 in /home/jtsarmento/.local/lib/python3.10/site-packages (from apache-airflow-providers-google) (0.6.1)
# Requirement already satisfied: sqlalchemy-spanner>=1.6.2 in /home/jtsarmento/.local/lib/python3.10/site-packages (from apache-airflow-providers-google) (1.10.0)
# Requirement already satisfied: google-cloud-batch>=0.13.0 in /home/jtsarmento/.local/lib/python3.10/site-packages (from apache-airflow-providers-google) (0.17.35)
# Requirement already satisfied: sqlalchemy-bigquery>=1.2.1 in /home/jtsarmento/.local/lib/python3.10/site-packages (from apache-airflow-providers-google) (1.13.0)
# Requirement already satisfied: types-protobuf!=5.29.1.20250402 in /home/jtsarmento/.local/lib/python3.10/site-packages (from apache-airflow-providers-google) (5.29.1.20250403)
# Requirement already satisfied: google-cloud-dataflow-client>=0.8.6 in /home/jtsarmento/.local/lib/python3.10/site-packages (from apache-airflow-providers-google) (0.8.17)
# Requirement already satisfied: google-cloud-orchestration-airflow>=1.10.0 in /home/jtsarmento/.local/lib/python3.10/site-packages (from apache-airflow-providers-google) (1.17.5)
# Requirement already satisfied: gcloud-aio-storage>=9.0.0 in /home/jtsarmento/.local/lib/python3.10/site-packages (from apache-airflow-providers-google) (9.4.0)
# Requirement already satisfied: google-cloud-speech>=2.18.0 in /home/jtsarmento/.local/lib/python3.10/site-packages (from apache-airflow-providers-google) (2.32.0)
# Collecting numpy
#   Using cached numpy-1.26.4-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (18.2 MB)
# Requirement already satisfied: tzdata>=2022.1 in /home/jtsarmento/.local/lib/python3.10/site-packages (from pandas) (2024.2)
# Requirement already satisfied: pytz>=2020.1 in /home/jtsarmento/.local/lib/python3.10/site-packages (from pandas) (2025.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /home/jtsarmento/.local/lib/python3.10/site-packages (from scikit-learn) (3.6.0)
# Requirement already satisfied: scipy>=1.6.0 in /home/jtsarmento/.local/lib/python3.10/site-packages (from scikit-learn) (1.15.2)
# Requirement already satisfied: pydata-google-auth>=1.5.0 in /home/jtsarmento/.local/lib/python3.10/site-packages (from pandas-gbq) (1.9.1)
# Requirement already satisfied: db-dtypes<2.0.0,>=1.0.4 in /home/jtsarmento/.local/lib/python3.10/site-packages (from pandas-gbq) (1.4.2)
# Requirement already satisfied: google-auth-oauthlib>=0.7.0 in /home/jtsarmento/.local/lib/python3.10/site-packages (from pandas-gbq) (1.2.2)
# Requirement already satisfied: setuptools in /usr/lib/python3/dist-packages (from pandas-gbq) (59.6.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in /home/jtsarmento/.local/lib/python3.10/site-packages (from google-auth) (4.7.2)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /home/jtsarmento/.local/lib/python3.10/site-packages (from google-auth) (0.4.1)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /home/jtsarmento/.local/lib/python3.10/site-packages (from google-auth) (5.5.0)
# Requirement already satisfied: more-itertools>=9.0.0 in /home/jtsarmento/.local/lib/python3.10/site-packages (from apache-airflow-providers-common-sql>=1.25.0->apache-airflow-core==3.0.0->apache-airflow) (10.7.0)
# Requirement already satisfied: sqlparse>=0.5.1 in /home/jtsarmento/.local/lib/python3.10/site-packages (from apache-airflow-providers-common-sql>=1.25.0->apache-airflow-core==3.0.0->apache-airflow) (0.5.1)
# Requirement already satisfied: aiologic>=0.14.0 in /home/jtsarmento/.local/lib/python3.10/site-packages (from apache-airflow-task-sdk<1.1.0,>=1.0.0->apache-airflow) (0.14.0)
# Requirement already satisfied: fsspec>=2023.10.0 in /home/jtsarmento/.local/lib/python3.10/site-packages (from apache-airflow-task-sdk<1.1.0,>=1.0.0->apache-airflow) (2025.3.2)
# Requirement already satisfied: retryhttp!=1.3.0,>=1.2.0 in /home/jtsarmento/.local/lib/python3.10/site-packages (from apache-airflow-task-sdk<1.1.0,>=1.0.0->apache-airflow) (1.3.2)
# Requirement already satisfied: structlog>=25.2.0 in /home/jtsarmento/.local/lib/python3.10/site-packages (from apache-airflow-task-sdk<1.1.0,>=1.0.0->apache-airflow) (25.3.0)
# Requirement already satisfied: msgspec>=0.19.0 in /home/jtsarmento/.local/lib/python3.10/site-packages (from apache-airflow-task-sdk<1.1.0,>=1.0.0->apache-airflow) (0.19.0)
# Requirement already satisfied: typing-extensions>=4 in /home/jtsarmento/.local/lib/python3.10/site-packages (from asgiref>=2.3.0->apache-airflow-core==3.0.0->apache-airflow) (4.12.2)
# Requirement already satisfied: backoff<3.0.0,>=1.0.0 in /home/jtsarmento/.local/lib/python3.10/site-packages (from gcloud-aio-auth>=5.2.0->apache-airflow-providers-google) (2.2.1)
# Requirement already satisfied: aiohttp<4.0.0,>=3.9.0 in /home/jtsarmento/.local/lib/python3.10/site-packages (from gcloud-aio-auth>=5.2.0->apache-airflow-providers-google) (3.11.13)
# Requirement already satisfied: chardet<6.0,>=2.0 in /usr/lib/python3/dist-packages (from gcloud-aio-auth>=5.2.0->apache-airflow-providers-google) (4.0.0)
# Requirement already satisfied: aiofiles<25.0.0,>=0.6.0 in /home/jtsarmento/.local/lib/python3.10/site-packages (from gcloud-aio-storage>=9.0.0->apache-airflow-providers-google) (24.1.0)
# Requirement already satisfied: decorator>4.1.2 in /home/jtsarmento/.local/lib/python3.10/site-packages (from gcsfs>=2023.10.0->apache-airflow-providers-google) (5.1.1)
# Requirement already satisfied: grpcio<2.0.0,>=1.59.0 in /home/jtsarmento/.local/lib/python3.10/site-packages (from google-ads>=26.0.0->apache-airflow-providers-google) (1.71.0)
# Requirement already satisfied: googleapis-common-protos<2.0.0,>=1.56.3 in /home/jtsarmento/.local/lib/python3.10/site-packages (from google-ads>=26.0.0->apache-airflow-providers-google) (1.66.0)
# Requirement already satisfied: protobuf<7.0.0,>=4.25.0 in /home/jtsarmento/.local/lib/python3.10/site-packages (from google-ads>=26.0.0->apache-airflow-providers-google) (5.29.4)
# Requirement already satisfied: PyYAML<7.0,>=5.1 in /home/jtsarmento/.local/lib/python3.10/site-packages (from google-ads>=26.0.0->apache-airflow-providers-google) (6.0.2)
# Requirement already satisfied: grpcio-status<2.0.0,>=1.59.0 in /home/jtsarmento/.local/lib/python3.10/site-packages (from google-ads>=26.0.0->apache-airflow-providers-google) (1.71.0)
# Requirement already satisfied: uritemplate<5,>=3.0.1 in /home/jtsarmento/.local/lib/python3.10/site-packages (from google-api-python-client>=2.0.2->apache-airflow-providers-google) (4.1.1)
# Requirement already satisfied: httplib2<1.dev0,>=0.19.0 in /usr/lib/python3/dist-packages (from google-api-python-client>=2.0.2->apache-airflow-providers-google) (0.20.2)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /home/jtsarmento/.local/lib/python3.10/site-packages (from google-auth-oauthlib>=0.7.0->pandas-gbq) (1.3.1)
# Requirement already satisfied: docstring-parser<1 in /home/jtsarmento/.local/lib/python3.10/site-packages (from google-cloud-aiplatform[evaluation]>=1.73.0->apache-airflow-providers-google) (0.16)
# Requirement already satisfied: google-cloud-resource-manager<3.0.0,>=1.3.3 in /home/jtsarmento/.local/lib/python3.10/site-packages (from google-cloud-aiplatform[evaluation]>=1.73.0->apache-airflow-providers-google) (1.14.2)
# Requirement already satisfied: shapely<3.0.0 in /home/jtsarmento/.local/lib/python3.10/site-packages (from google-cloud-aiplatform[evaluation]>=1.73.0->apache-airflow-providers-google) (2.1.0)
# Collecting scikit-learn
#   Using cached scikit_learn-1.5.2-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (13.3 MB)
# Requirement already satisfied: ruamel.yaml in /home/jtsarmento/.local/lib/python3.10/site-packages (from google-cloud-aiplatform[evaluation]>=1.73.0->apache-airflow-providers-google) (0.18.10)
# Requirement already satisfied: tqdm>=4.23.0 in /home/jtsarmento/.local/lib/python3.10/site-packages (from google-cloud-aiplatform[evaluation]>=1.73.0->apache-airflow-providers-google) (4.67.1)
# Requirement already satisfied: grpc-google-iam-v1<1.0.0,>=0.14.0 in /home/jtsarmento/.local/lib/python3.10/site-packages (from google-cloud-alloydb>=0.4.0->apache-airflow-providers-google) (0.14.2)
# Requirement already satisfied: google-resumable-media<3.0.0,>=2.0.0 in /home/jtsarmento/.local/lib/python3.10/site-packages (from google-cloud-bigquery!=3.21.*,!=3.22.0,!=3.23.*,>=3.4.0->apache-airflow-providers-google) (2.7.2)
# Requirement already satisfied: google-cloud-core<3.0.0,>=2.4.1 in /home/jtsarmento/.local/lib/python3.10/site-packages (from google-cloud-bigquery!=3.21.*,!=3.22.0,!=3.23.*,>=3.4.0->apache-airflow-providers-google) (2.4.3)
# Requirement already satisfied: google-crc32c<2.0.0dev,>=1.5.0 in /home/jtsarmento/.local/lib/python3.10/site-packages (from google-cloud-bigtable>=2.17.0->apache-airflow-providers-google) (1.7.1)
# Requirement already satisfied: google-cloud-audit-log<1.0.0,>=0.3.1 in /home/jtsarmento/.local/lib/python3.10/site-packages (from google-cloud-logging>=3.5.0->apache-airflow-providers-google) (0.3.2)
# Requirement already satisfied: google-cloud-appengine-logging<2.0.0,>=0.1.3 in /home/jtsarmento/.local/lib/python3.10/site-packages (from google-cloud-logging>=3.5.0->apache-airflow-providers-google) (1.6.1)
# Requirement already satisfied: opentelemetry-sdk>=1.27.0 in /home/jtsarmento/.local/lib/python3.10/site-packages (from google-cloud-pubsub>=2.21.3->apache-airflow-providers-google) (1.32.1)
# Requirement already satisfied: grpc-interceptor>=0.15.4 in /home/jtsarmento/.local/lib/python3.10/site-packages (from google-cloud-spanner!=3.49.0,>=3.11.1->apache-airflow-providers-google) (0.15.4)
# Requirement already satisfied: anyio in /home/jtsarmento/.local/lib/python3.10/site-packages (from httpx>=0.25.0->apache-airflow-core==3.0.0->apache-airflow) (4.7.0)
# Requirement already satisfied: idna in /usr/lib/python3/dist-packages (from httpx>=0.25.0->apache-airflow-core==3.0.0->apache-airflow) (3.3)
# Requirement already satisfied: certifi in /usr/lib/python3/dist-packages (from httpx>=0.25.0->apache-airflow-core==3.0.0->apache-airflow) (2020.6.20)
# Requirement already satisfied: httpcore==1.* in /home/jtsarmento/.local/lib/python3.10/site-packages (from httpx>=0.25.0->apache-airflow-core==3.0.0->apache-airflow) (1.0.7)
# Requirement already satisfied: h11<0.15,>=0.13 in /home/jtsarmento/.local/lib/python3.10/site-packages (from httpcore==1.*->httpx>=0.25.0->apache-airflow-core==3.0.0->apache-airflow) (0.14.0)
# Requirement already satisfied: cattrs>=1.3 in /home/jtsarmento/.local/lib/python3.10/site-packages (from looker-sdk!=24.18.0,>=22.4.0->apache-airflow-providers-google) (24.1.3)
# Requirement already satisfied: pyasn1<0.7.0,>=0.4.6 in /usr/lib/python3/dist-packages (from pyasn1-modules>=0.2.1->google-auth) (0.4.8)
# Requirement already satisfied: six>=1.5 in /usr/lib/python3/dist-packages (from python-dateutil>=2.7.0->apache-airflow-core==3.0.0->apache-airflow) (1.16.0)
# Requirement already satisfied: text-unidecode>=1.3 in /home/jtsarmento/.local/lib/python3.10/site-packages (from python-slugify>=5.0->apache-airflow-core==3.0.0->apache-airflow) (1.3)
# Requirement already satisfied: async-timeout<6.0,>=4.0 in /home/jtsarmento/.local/lib/python3.10/site-packages (from aiohttp<4.0.0,>=3.9.0->gcloud-aio-auth>=5.2.0->apache-airflow-providers-google) (5.0.1)
# Requirement already satisfied: propcache>=0.2.0 in /home/jtsarmento/.local/lib/python3.10/site-packages (from aiohttp<4.0.0,>=3.9.0->gcloud-aio-auth>=5.2.0->apache-airflow-providers-google) (0.3.0)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /home/jtsarmento/.local/lib/python3.10/site-packages (from aiohttp<4.0.0,>=3.9.0->gcloud-aio-auth>=5.2.0->apache-airflow-providers-google) (1.18.3)
# Requirement already satisfied: frozenlist>=1.1.1 in /home/jtsarmento/.local/lib/python3.10/site-packages (from aiohttp<4.0.0,>=3.9.0->gcloud-aio-auth>=5.2.0->apache-airflow-providers-google) (1.5.0)
# Requirement already satisfied: aiosignal>=1.1.2 in /home/jtsarmento/.local/lib/python3.10/site-packages (from aiohttp<4.0.0,>=3.9.0->gcloud-aio-auth>=5.2.0->apache-airflow-providers-google) (1.3.2)
# Requirement already satisfied: multidict<7.0,>=4.5 in /home/jtsarmento/.local/lib/python3.10/site-packages (from aiohttp<4.0.0,>=3.9.0->gcloud-aio-auth>=5.2.0->apache-airflow-providers-google) (6.1.0)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in /home/jtsarmento/.local/lib/python3.10/site-packages (from aiohttp<4.0.0,>=3.9.0->gcloud-aio-auth>=5.2.0->apache-airflow-providers-google) (2.5.0)
# Requirement already satisfied: wrapt>=1.16.0 in /home/jtsarmento/.local/lib/python3.10/site-packages (from aiologic>=0.14.0->apache-airflow-task-sdk<1.1.0,>=1.0.0->apache-airflow) (1.17.2)
# Requirement already satisfied: Mako in /home/jtsarmento/.local/lib/python3.10/site-packages (from alembic<2.0,>=1.13.1->apache-airflow-core==3.0.0->apache-airflow) (1.3.10)
# Requirement already satisfied: starlette>=0.30.0 in /home/jtsarmento/.local/lib/python3.10/site-packages (from cadwyn>=5.2.1->apache-airflow-core==3.0.0->apache-airflow) (0.46.2)
# Requirement already satisfied: backports-strenum<2,>=1.3.1 in /home/jtsarmento/.local/lib/python3.10/site-packages (from cadwyn>=5.2.1->apache-airflow-core==3.0.0->apache-airflow) (1.3.1)
# Requirement already satisfied: exceptiongroup>=1.1.1 in /home/jtsarmento/.local/lib/python3.10/site-packages (from cattrs>=1.3->looker-sdk!=24.18.0,>=22.4.0->apache-airflow-providers-google) (1.2.1)
# Requirement already satisfied: cffi>=1.12 in /home/jtsarmento/.local/lib/python3.10/site-packages (from cryptography>=41.0.0->apache-airflow-core==3.0.0->apache-airflow) (1.17.1)
# Requirement already satisfied: email-validator>=2.0.0 in /home/jtsarmento/.local/lib/python3.10/site-packages (from fastapi[standard]!=0.115.10,>=0.115.0->apache-airflow-core==3.0.0->apache-airflow) (2.2.0)
# Requirement already satisfied: uvicorn[standard]>=0.12.0 in /home/jtsarmento/.local/lib/python3.10/site-packages (from fastapi[standard]!=0.115.10,>=0.115.0->apache-airflow-core==3.0.0->apache-airflow) (0.34.2)
# Requirement already satisfied: fastapi-cli[standard]>=0.0.5 in /home/jtsarmento/.local/lib/python3.10/site-packages (from fastapi[standard]!=0.115.10,>=0.115.0->apache-airflow-core==3.0.0->apache-airflow) (0.0.7)
# Requirement already satisfied: python-multipart>=0.0.18 in /home/jtsarmento/.local/lib/python3.10/site-packages (from fastapi[standard]!=0.115.10,>=0.115.0->apache-airflow-core==3.0.0->apache-airflow) (0.0.20)
# Requirement already satisfied: blinker>=1.6.2 in /home/jtsarmento/.local/lib/python3.10/site-packages (from flask>=2.1.1->apache-airflow-core==3.0.0->apache-airflow) (1.9.0)
# Requirement already satisfied: Werkzeug>=3.0.0 in /home/jtsarmento/.local/lib/python3.10/site-packages (from flask>=2.1.1->apache-airflow-core==3.0.0->apache-airflow) (3.1.3)
# Requirement already satisfied: click>=8.1.3 in /home/jtsarmento/.local/lib/python3.10/site-packages (from flask>=2.1.1->apache-airflow-core==3.0.0->apache-airflow) (8.1.8)
# Requirement already satisfied: gitdb<5,>=4.0.1 in /home/jtsarmento/.local/lib/python3.10/site-packages (from gitpython>=3.1.40->apache-airflow-core==3.0.0->apache-airflow) (4.0.12)
# Requirement already satisfied: pyparsing!=3.0.0,!=3.0.1,!=3.0.2,!=3.0.3,<4,>=2.4.2 in /usr/lib/python3/dist-packages (from httplib2<1.dev0,>=0.19.0->google-api-python-client>=2.0.2->apache-airflow-providers-google) (2.4.7)
# Requirement already satisfied: zipp>=0.5 in /usr/lib/python3/dist-packages (from importlib-metadata>=6.5->apache-airflow-core==3.0.0->apache-airflow) (1.0.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /home/jtsarmento/.local/lib/python3.10/site-packages (from jinja2>=3.1.5->apache-airflow-core==3.0.0->apache-airflow) (3.0.2)
# Requirement already satisfied: referencing>=0.28.4 in /home/jtsarmento/.local/lib/python3.10/site-packages (from jsonschema>=4.19.1->apache-airflow-core==3.0.0->apache-airflow) (0.35.1)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /home/jtsarmento/.local/lib/python3.10/site-packages (from jsonschema>=4.19.1->apache-airflow-core==3.0.0->apache-airflow) (2024.10.1)
# Requirement already satisfied: rpds-py>=0.7.1 in /home/jtsarmento/.local/lib/python3.10/site-packages (from jsonschema>=4.19.1->apache-airflow-core==3.0.0->apache-airflow) (0.20.1)
# Requirement already satisfied: uc-micro-py in /home/jtsarmento/.local/lib/python3.10/site-packages (from linkify-it-py>=2.0.0->apache-airflow-core==3.0.0->apache-airflow) (1.0.3)
# Requirement already satisfied: wirerope>=0.4.7 in /home/jtsarmento/.local/lib/python3.10/site-packages (from methodtools>=0.4.7->apache-airflow-core==3.0.0->apache-airflow) (1.0.0)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-grpc==1.32.1 in /home/jtsarmento/.local/lib/python3.10/site-packages (from opentelemetry-exporter-otlp>=1.24.0->apache-airflow-core==3.0.0->apache-airflow) (1.32.1)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-http==1.32.1 in /home/jtsarmento/.local/lib/python3.10/site-packages (from opentelemetry-exporter-otlp>=1.24.0->apache-airflow-core==3.0.0->apache-airflow) (1.32.1)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-common==1.32.1 in /home/jtsarmento/.local/lib/python3.10/site-packages (from opentelemetry-exporter-otlp-proto-grpc==1.32.1->opentelemetry-exporter-otlp>=1.24.0->apache-airflow-core==3.0.0->apache-airflow) (1.32.1)
# Requirement already satisfied: opentelemetry-proto==1.32.1 in /home/jtsarmento/.local/lib/python3.10/site-packages (from opentelemetry-exporter-otlp-proto-grpc==1.32.1->opentelemetry-exporter-otlp>=1.24.0->apache-airflow-core==3.0.0->apache-airflow) (1.32.1)
# Requirement already satisfied: opentelemetry-semantic-conventions==0.53b1 in /home/jtsarmento/.local/lib/python3.10/site-packages (from opentelemetry-sdk>=1.27.0->google-cloud-pubsub>=2.21.3->apache-airflow-providers-google) (0.53b1)
# Requirement already satisfied: annotated-types>=0.6.0 in /home/jtsarmento/.local/lib/python3.10/site-packages (from pydantic>=2.11.0->apache-airflow-core==3.0.0->apache-airflow) (0.7.0)
# Requirement already satisfied: typing-inspection>=0.4.0 in /home/jtsarmento/.local/lib/python3.10/site-packages (from pydantic>=2.11.0->apache-airflow-core==3.0.0->apache-airflow) (0.4.0)
# Requirement already satisfied: pydantic-core==2.33.1 in /home/jtsarmento/.local/lib/python3.10/site-packages (from pydantic>=2.11.0->apache-airflow-core==3.0.0->apache-airflow) (2.33.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/jtsarmento/.local/lib/python3.10/site-packages (from requests<3,>=2.31.0->apache-airflow-core==3.0.0->apache-airflow) (3.3.2)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/jtsarmento/.local/lib/python3.10/site-packages (from requests<3,>=2.31.0->apache-airflow-core==3.0.0->apache-airflow) (2.0.7)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/lib/python3/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib>=0.7.0->pandas-gbq) (3.2.0)
# Requirement already satisfied: types-requests in /home/jtsarmento/.local/lib/python3.10/site-packages (from retryhttp!=1.3.0,>=1.2.0->apache-airflow-task-sdk<1.1.0,>=1.0.0->apache-airflow) (2.32.0.20241016)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /home/jtsarmento/.local/lib/python3.10/site-packages (from rich>=13.6.0->apache-airflow-core==3.0.0->apache-airflow) (3.0.0)
# Requirement already satisfied: greenlet!=0.4.17 in /home/jtsarmento/.local/lib/python3.10/site-packages (from sqlalchemy<2.0,>=1.4.49->apache-airflow-core==3.0.0->apache-airflow) (3.1.1)
# Requirement already satisfied: sniffio>=1.1 in /home/jtsarmento/.local/lib/python3.10/site-packages (from anyio->httpx>=0.25.0->apache-airflow-core==3.0.0->apache-airflow) (1.3.1)
# Requirement already satisfied: ruamel.yaml.clib>=0.2.7 in /home/jtsarmento/.local/lib/python3.10/site-packages (from ruamel.yaml->google-cloud-aiplatform[evaluation]>=1.73.0->apache-airflow-providers-google) (0.2.12)
# Requirement already satisfied: pycparser in /home/jtsarmento/.local/lib/python3.10/site-packages (from cffi>=1.12->cryptography>=41.0.0->apache-airflow-core==3.0.0->apache-airflow) (2.22)
# Requirement already satisfied: dnspython>=2.0.0 in /home/jtsarmento/.local/lib/python3.10/site-packages (from email-validator>=2.0.0->fastapi[standard]!=0.115.10,>=0.115.0->apache-airflow-core==3.0.0->apache-airflow) (2.7.0)
# Requirement already satisfied: typer>=0.12.3 in /home/jtsarmento/.local/lib/python3.10/site-packages (from fastapi-cli[standard]>=0.0.5->fastapi[standard]!=0.115.10,>=0.115.0->apache-airflow-core==3.0.0->apache-airflow) (0.15.2)
# Requirement already satisfied: rich-toolkit>=0.11.1 in /home/jtsarmento/.local/lib/python3.10/site-packages (from fastapi-cli[standard]>=0.0.5->fastapi[standard]!=0.115.10,>=0.115.0->apache-airflow-core==3.0.0->apache-airflow) (0.14.3)
# Requirement already satisfied: smmap<6,>=3.0.1 in /home/jtsarmento/.local/lib/python3.10/site-packages (from gitdb<5,>=4.0.1->gitpython>=3.1.40->apache-airflow-core==3.0.0->apache-airflow) (5.0.2)
# Requirement already satisfied: mdurl~=0.1 in /home/jtsarmento/.local/lib/python3.10/site-packages (from markdown-it-py>=2.2.0->rich>=13.6.0->apache-airflow-core==3.0.0->apache-airflow) (0.1.2)
# Requirement already satisfied: python-dotenv>=0.13 in /home/jtsarmento/.local/lib/python3.10/site-packages (from uvicorn[standard]>=0.12.0->fastapi[standard]!=0.115.10,>=0.115.0->apache-airflow-core==3.0.0->apache-airflow) (1.0.1)
# Requirement already satisfied: httptools>=0.6.3 in /home/jtsarmento/.local/lib/python3.10/site-packages (from uvicorn[standard]>=0.12.0->fastapi[standard]!=0.115.10,>=0.115.0->apache-airflow-core==3.0.0->apache-airflow) (0.6.4)
# Requirement already satisfied: watchfiles>=0.13 in /home/jtsarmento/.local/lib/python3.10/site-packages (from uvicorn[standard]>=0.12.0->fastapi[standard]!=0.115.10,>=0.115.0->apache-airflow-core==3.0.0->apache-airflow) (1.0.5)
# Requirement already satisfied: uvloop!=0.15.0,!=0.15.1,>=0.14.0 in /home/jtsarmento/.local/lib/python3.10/site-packages (from uvicorn[standard]>=0.12.0->fastapi[standard]!=0.115.10,>=0.115.0->apache-airflow-core==3.0.0->apache-airflow) (0.21.0)
# Requirement already satisfied: websockets>=10.4 in /home/jtsarmento/.local/lib/python3.10/site-packages (from uvicorn[standard]>=0.12.0->fastapi[standard]!=0.115.10,>=0.115.0->apache-airflow-core==3.0.0->apache-airflow) (15.0.1)
# Requirement already satisfied: shellingham>=1.3.0 in /usr/lib/python3/dist-packages (from typer>=0.12.3->fastapi-cli[standard]>=0.0.5->fastapi[standard]!=0.115.10,>=0.115.0->apache-airflow-core==3.0.0->apache-airflow) (1.4.0)
# Installing collected packages: numpy, scikit-learn
#   Attempting uninstall: numpy
#     Found existing installation: numpy 2.2.5
#     Uninstalling numpy-2.2.5:
#       Successfully uninstalled numpy-2.2.5
#   Attempting uninstall: scikit-learn
#     Found existing installation: scikit-learn 1.6.1
#     Uninstalling scikit-learn-1.6.1:
#       Successfully uninstalled scikit-learn-1.6.1
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# streamlit 1.44.1 requires packaging<25,>=20, but you have packaging 25.0 which is incompatible.
# Successfully installed numpy-1.26.4 scikit-learn-1.5.2
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[2], line 4
#       1 get_ipython().system('pip install      apache-airflow apache-airflow-providers-google      pandas numpy scikit-learn joblib holidays      pandas-gbq google-auth numpy')
#       3 from datetime import datetime, timedelta, date
# ----> 4 import pandas as pd
#       5 import numpy as np
#       6 from sklearn.ensemble import RandomForestRegressor
#
# File ~/.local/lib/python3.10/site-packages/pandas/__init__.py:46
#      43 # let init-time option registration happen
#      44 import pandas.core.config_init  # pyright: ignore[reportUnusedImport] # noqa: F401
# ---> 46 from pandas.core.api import (
#      47     # dtype
#      48     ArrowDtype,
#      49     Int8Dtype,
#      50     Int16Dtype,
#      51     Int32Dtype,
#      52     Int64Dtype,
#      53     UInt8Dtype,
#      54     UInt16Dtype,
#      55     UInt32Dtype,
#      56     UInt64Dtype,
#      57     Float32Dtype,
#      58     Float64Dtype,
#      59     CategoricalDtype,
#      60     PeriodDtype,
#      61     IntervalDtype,
#      62     DatetimeTZDtype,
#      63     StringDtype,
#      64     BooleanDtype,
#      65     # missing
#      66     NA,
#      67     isna,
#      68     isnull,
#      69     notna,
#      70     notnull,
#      71     # indexes
#      72     Index,
#      73     CategoricalIndex,
#      74     RangeIndex,
#      75     MultiIndex,
#      76     IntervalIndex,
#      77     TimedeltaIndex,
#      78     DatetimeIndex,
#      79     PeriodIndex,
#      80     IndexSlice,
#      81     # tseries
#      82     NaT,
#      83     Period,
#      84     period_range,
#      85     Timedelta,
#      86     timedelta_range,
#      87     Timestamp,
#      88     date_range,
#      89     bdate_range,
#      90     Interval,
#      91     interval_range,
#      92     DateOffset,
#      93     # conversion
#      94     to_numeric,
#      95     to_datetime,
#      96     to_timedelta,
#      97     # misc
#      98     Flags,
#      99     Grouper,
#     100     factorize,
#     101     unique,
#     102     value_counts,
#     103     NamedAgg,
#     104     array,
#     105     Categorical,
#     106     set_eng_float_format,
#     107     Series,
#     108     DataFrame,
#     109 )
#     111 from pandas.core.dtypes.dtypes import SparseDtype
#     113 from pandas.tseries.api import infer_freq
#
# File ~/.local/lib/python3.10/site-packages/pandas/core/api.py:1
# ----> 1 from pandas._libs import (
#       2     NaT,
#       3     Period,
#       4     Timedelta,
#       5     Timestamp,
#       6 )
#       7 from pandas._libs.missing import NA
#       9 from pandas.core.dtypes.dtypes import (
#      10     ArrowDtype,
#      11     CategoricalDtype,
#    (...)
#      14     PeriodDtype,
#      15 )
#
# File ~/.local/lib/python3.10/site-packages/pandas/_libs/__init__.py:18
#      16 import pandas._libs.pandas_parser  # noqa: E501 # isort: skip # type: ignore[reportUnusedImport]
#      17 import pandas._libs.pandas_datetime  # noqa: F401,E501 # isort: skip # type: ignore[reportUnusedImport]
# ---> 18 from pandas._libs.interval import Interval
#      19 from pandas._libs.tslibs import (
#      20     NaT,
#      21     NaTType,
#    (...)
#      26     iNaT,
#      27 )
#
# File interval.pyx:1, in init pandas._libs.interval()
#
# ValueError: numpy.dtype size changed, may indicate binary incompatibility. Expected 96 from C header, got 88 from PyObject

# %%
# 1. Remove the broken installs
# !pip uninstall -y numpy pandas scipy scikit-learn joblib

# 2. Reinstall cleanly
# !pip install numpy pandas scipy scikit-learn joblib

# 3. (Re)install your other deps
# !pip install pandas-gbq google-auth holidays apache-airflow-providers-google
# Out:
# Found existing installation: numpy 1.26.4
# Uninstalling numpy-1.26.4:
#   Successfully uninstalled numpy-1.26.4
# Found existing installation: pandas 2.1.4
# Uninstalling pandas-2.1.4:
#   Successfully uninstalled pandas-2.1.4
# Found existing installation: scipy 1.15.2
# Uninstalling scipy-1.15.2:
#   Successfully uninstalled scipy-1.15.2
# Found existing installation: scikit-learn 1.5.2
# Uninstalling scikit-learn-1.5.2:
#   Successfully uninstalled scikit-learn-1.5.2
# Found existing installation: joblib 1.4.2
# Uninstalling joblib-1.4.2:
#   Successfully uninstalled joblib-1.4.2
# Defaulting to user installation because normal site-packages is not writeable
# Collecting numpy
#   Using cached numpy-2.2.5-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (16.4 MB)
# Collecting pandas
#   Using cached pandas-2.2.3-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (13.1 MB)
# Collecting scipy
#   Using cached scipy-1.15.2-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (37.6 MB)
# Collecting scikit-learn
#   Using cached scikit_learn-1.6.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (13.5 MB)
# Collecting joblib
#   Using cached joblib-1.4.2-py3-none-any.whl (301 kB)
# Requirement already satisfied: python-dateutil>=2.8.2 in /home/jtsarmento/.local/lib/python3.10/site-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /home/jtsarmento/.local/lib/python3.10/site-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /home/jtsarmento/.local/lib/python3.10/site-packages (from pandas) (2024.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /home/jtsarmento/.local/lib/python3.10/site-packages (from scikit-learn) (3.6.0)
# Requirement already satisfied: six>=1.5 in /usr/lib/python3/dist-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)
# Installing collected packages: numpy, joblib, scipy, pandas, scikit-learn
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# streamlit 1.44.1 requires packaging<25,>=20, but you have packaging 25.0 which is incompatible.
# apache-airflow-providers-google 15.1.0 requires pandas<2.2,>=2.1.2, but you have pandas 2.2.3 which is incompatible.
# Successfully installed joblib-1.4.2 numpy-2.2.5 pandas-2.2.3 scikit-learn-1.6.1 scipy-1.15.2
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: pandas-gbq in /home/jtsarmento/.local/lib/python3.10/site-packages (0.28.0)
# Requirement already satisfied: google-auth in /home/jtsarmento/.local/lib/python3.10/site-packages (2.37.0)
# Requirement already satisfied: holidays in /home/jtsarmento/.local/lib/python3.10/site-packages (0.71)
# Requirement already satisfied: apache-airflow-providers-google in /home/jtsarmento/.local/lib/python3.10/site-packages (15.1.0)
# Requirement already satisfied: pyarrow>=4.0.0 in /home/jtsarmento/.local/lib/python3.10/site-packages (from pandas-gbq) (19.0.1)
# Requirement already satisfied: google-auth-oauthlib>=0.7.0 in /home/jtsarmento/.local/lib/python3.10/site-packages (from pandas-gbq) (1.2.2)
# Requirement already satisfied: pandas>=1.1.4 in /home/jtsarmento/.local/lib/python3.10/site-packages (from pandas-gbq) (2.2.3)
# Requirement already satisfied: pydata-google-auth>=1.5.0 in /home/jtsarmento/.local/lib/python3.10/site-packages (from pandas-gbq) (1.9.1)
# Requirement already satisfied: google-cloud-bigquery<4.0.0dev,>=3.4.2 in /home/jtsarmento/.local/lib/python3.10/site-packages (from pandas-gbq) (3.31.0)
# Requirement already satisfied: google-api-core<3.0.0dev,>=2.10.2 in /home/jtsarmento/.local/lib/python3.10/site-packages (from pandas-gbq) (2.24.0)
# Requirement already satisfied: packaging>=22.0.0 in /home/jtsarmento/.local/lib/python3.10/site-packages (from pandas-gbq) (25.0)
# Requirement already satisfied: numpy>=1.18.1 in /home/jtsarmento/.local/lib/python3.10/site-packages (from pandas-gbq) (2.2.5)
# Requirement already satisfied: db-dtypes<2.0.0,>=1.0.4 in /home/jtsarmento/.local/lib/python3.10/site-packages (from pandas-gbq) (1.4.2)
# Requirement already satisfied: setuptools in /usr/lib/python3/dist-packages (from pandas-gbq) (59.6.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in /home/jtsarmento/.local/lib/python3.10/site-packages (from google-auth) (4.7.2)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /home/jtsarmento/.local/lib/python3.10/site-packages (from google-auth) (0.4.1)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /home/jtsarmento/.local/lib/python3.10/site-packages (from google-auth) (5.5.0)
# Requirement already satisfied: python-dateutil in /home/jtsarmento/.local/lib/python3.10/site-packages (from holidays) (2.8.2)
# Requirement already satisfied: google-ads>=26.0.0 in /home/jtsarmento/.local/lib/python3.10/site-packages (from apache-airflow-providers-google) (26.1.0)
# Requirement already satisfied: google-cloud-dataproc>=5.12.0 in /home/jtsarmento/.local/lib/python3.10/site-packages (from apache-airflow-providers-google) (5.18.1)
# Requirement already satisfied: google-cloud-bigquery-datatransfer>=3.13.0 in /home/jtsarmento/.local/lib/python3.10/site-packages (from apache-airflow-providers-google) (3.19.1)
# Requirement already satisfied: python-slugify>=7.0.0 in /home/jtsarmento/.local/lib/python3.10/site-packages (from apache-airflow-providers-google) (8.0.4)
# Requirement already satisfied: apache-airflow>=2.9.0 in /home/jtsarmento/.local/lib/python3.10/site-packages (from apache-airflow-providers-google) (3.0.0)
# Requirement already satisfied: immutabledict>=4.2.0 in /home/jtsarmento/.local/lib/python3.10/site-packages (from apache-airflow-providers-google) (4.2.1)
# Requirement already satisfied: google-cloud-workflows>=1.10.0 in /home/jtsarmento/.local/lib/python3.10/site-packages (from apache-airflow-providers-google) (1.18.1)
# Requirement already satisfied: google-api-python-client>=2.0.2 in /home/jtsarmento/.local/lib/python3.10/site-packages (from apache-airflow-providers-google) (2.156.0)
# Requirement already satisfied: google-cloud-batch>=0.13.0 in /home/jtsarmento/.local/lib/python3.10/site-packages (from apache-airflow-providers-google) (0.17.35)
# Requirement already satisfied: asgiref>=3.5.2 in /home/jtsarmento/.local/lib/python3.10/site-packages (from apache-airflow-providers-google) (3.7.2)
# Requirement already satisfied: google-cloud-speech>=2.18.0 in /home/jtsarmento/.local/lib/python3.10/site-packages (from apache-airflow-providers-google) (2.32.0)
# Requirement already satisfied: google-cloud-translate>=3.16.0 in /home/jtsarmento/.local/lib/python3.10/site-packages (from apache-airflow-providers-google) (3.20.2)
# Requirement already satisfied: sqlalchemy-bigquery>=1.2.1 in /home/jtsarmento/.local/lib/python3.10/site-packages (from apache-airflow-providers-google) (1.13.0)
# Requirement already satisfied: google-cloud-alloydb>=0.4.0 in /home/jtsarmento/.local/lib/python3.10/site-packages (from apache-airflow-providers-google) (0.4.5)
# Requirement already satisfied: google-cloud-bigtable>=2.17.0 in /home/jtsarmento/.local/lib/python3.10/site-packages (from apache-airflow-providers-google) (2.30.1)
# Requirement already satisfied: google-cloud-automl>=2.12.0 in /home/jtsarmento/.local/lib/python3.10/site-packages (from apache-airflow-providers-google) (2.16.3)
# Requirement already satisfied: google-auth-httplib2>=0.0.1 in /home/jtsarmento/.local/lib/python3.10/site-packages (from apache-airflow-providers-google) (0.2.0)
# Requirement already satisfied: google-cloud-language>=2.9.0 in /home/jtsarmento/.local/lib/python3.10/site-packages (from apache-airflow-providers-google) (2.17.1)
# Requirement already satisfied: google-cloud-texttospeech>=2.14.1 in /home/jtsarmento/.local/lib/python3.10/site-packages (from apache-airflow-providers-google) (2.26.0)
# Requirement already satisfied: types-protobuf!=5.29.1.20250402 in /home/jtsarmento/.local/lib/python3.10/site-packages (from apache-airflow-providers-google) (5.29.1.20250403)
# Requirement already satisfied: tenacity>=8.1.0 in /home/jtsarmento/.local/lib/python3.10/site-packages (from apache-airflow-providers-google) (9.1.2)
# Requirement already satisfied: google-cloud-orchestration-airflow>=1.10.0 in /home/jtsarmento/.local/lib/python3.10/site-packages (from apache-airflow-providers-google) (1.17.5)
# Requirement already satisfied: google-cloud-kms>=2.15.0 in /home/jtsarmento/.local/lib/python3.10/site-packages (from apache-airflow-providers-google) (3.4.1)
# Requirement already satisfied: gcloud-aio-storage>=9.0.0 in /home/jtsarmento/.local/lib/python3.10/site-packages (from apache-airflow-providers-google) (9.4.0)
# Requirement already satisfied: apache-airflow-providers-common-sql>=1.20.0 in /home/jtsarmento/.local/lib/python3.10/site-packages (from apache-airflow-providers-google) (1.26.0)
# Requirement already satisfied: google-cloud-managedkafka>=0.1.6 in /home/jtsarmento/.local/lib/python3.10/site-packages (from apache-airflow-providers-google) (0.1.9)
# Requirement already satisfied: apache-airflow-providers-common-compat>=1.4.0 in /home/jtsarmento/.local/lib/python3.10/site-packages (from apache-airflow-providers-google) (1.6.0)
# Requirement already satisfied: google-cloud-pubsub>=2.21.3 in /home/jtsarmento/.local/lib/python3.10/site-packages (from apache-airflow-providers-google) (2.29.0)
# Requirement already satisfied: google-cloud-storage>=2.7.0 in /home/jtsarmento/.local/lib/python3.10/site-packages (from apache-airflow-providers-google) (2.19.0)
# Requirement already satisfied: google-cloud-container>=2.52.0 in /home/jtsarmento/.local/lib/python3.10/site-packages (from apache-airflow-providers-google) (2.56.1)
# Requirement already satisfied: google-cloud-compute>=1.10.0 in /home/jtsarmento/.local/lib/python3.10/site-packages (from apache-airflow-providers-google) (1.30.0)
# Requirement already satisfied: google-cloud-monitoring>=2.18.0 in /home/jtsarmento/.local/lib/python3.10/site-packages (from apache-airflow-providers-google) (2.27.1)
# Requirement already satisfied: gcloud-aio-auth>=5.2.0 in /home/jtsarmento/.local/lib/python3.10/site-packages (from apache-airflow-providers-google) (5.4.1)
# Requirement already satisfied: google-cloud-secret-manager>=2.16.0 in /home/jtsarmento/.local/lib/python3.10/site-packages (from apache-airflow-providers-google) (2.23.3)
# Requirement already satisfied: grpcio-gcp>=0.2.2 in /home/jtsarmento/.local/lib/python3.10/site-packages (from apache-airflow-providers-google) (0.2.2)
# Requirement already satisfied: PyOpenSSL>=23.0.0 in /home/jtsarmento/.local/lib/python3.10/site-packages (from apache-airflow-providers-google) (25.0.0)
# Collecting pandas>=1.1.4
#   Using cached pandas-2.1.4-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (12.3 MB)
# Requirement already satisfied: google-cloud-dataproc-metastore>=1.12.0 in /home/jtsarmento/.local/lib/python3.10/site-packages (from apache-airflow-providers-google) (1.18.2)
# Requirement already satisfied: google-cloud-dataplex>=2.6.0 in /home/jtsarmento/.local/lib/python3.10/site-packages (from apache-airflow-providers-google) (2.10.1)
# Requirement already satisfied: google-cloud-datacatalog>=3.23.0 in /home/jtsarmento/.local/lib/python3.10/site-packages (from apache-airflow-providers-google) (3.27.0)
# Requirement already satisfied: httpx>=0.25.0 in /home/jtsarmento/.local/lib/python3.10/site-packages (from apache-airflow-providers-google) (0.28.1)
# Requirement already satisfied: gcsfs>=2023.10.0 in /home/jtsarmento/.local/lib/python3.10/site-packages (from apache-airflow-providers-google) (2025.3.2)
# Requirement already satisfied: proto-plus>=1.19.6 in /home/jtsarmento/.local/lib/python3.10/site-packages (from apache-airflow-providers-google) (1.25.0)
# Requirement already satisfied: google-cloud-logging>=3.5.0 in /home/jtsarmento/.local/lib/python3.10/site-packages (from apache-airflow-providers-google) (3.12.1)
# Requirement already satisfied: looker-sdk!=24.18.0,>=22.4.0 in /home/jtsarmento/.local/lib/python3.10/site-packages (from apache-airflow-providers-google) (25.4.0)
# Requirement already satisfied: google-cloud-vision>=3.4.0 in /home/jtsarmento/.local/lib/python3.10/site-packages (from apache-airflow-providers-google) (3.10.1)
# Requirement already satisfied: google-cloud-redis>=2.12.0 in /home/jtsarmento/.local/lib/python3.10/site-packages (from apache-airflow-providers-google) (2.18.1)
# Requirement already satisfied: google-cloud-videointelligence>=2.11.0 in /home/jtsarmento/.local/lib/python3.10/site-packages (from apache-airflow-providers-google) (2.16.1)
# Requirement already satisfied: gcloud-aio-bigquery>=6.1.2 in /home/jtsarmento/.local/lib/python3.10/site-packages (from apache-airflow-providers-google) (7.1.0)
# Requirement already satisfied: google-cloud-aiplatform[evaluation]>=1.73.0 in /home/jtsarmento/.local/lib/python3.10/site-packages (from apache-airflow-providers-google) (1.90.0)
# Requirement already satisfied: google-cloud-os-login>=2.9.1 in /home/jtsarmento/.local/lib/python3.10/site-packages (from apache-airflow-providers-google) (2.17.1)
# Requirement already satisfied: google-cloud-dataflow-client>=0.8.6 in /home/jtsarmento/.local/lib/python3.10/site-packages (from apache-airflow-providers-google) (0.8.17)
# Requirement already satisfied: sqlalchemy-spanner>=1.6.2 in /home/jtsarmento/.local/lib/python3.10/site-packages (from apache-airflow-providers-google) (1.10.0)
# Requirement already satisfied: google-cloud-tasks>=2.13.0 in /home/jtsarmento/.local/lib/python3.10/site-packages (from apache-airflow-providers-google) (2.19.2)
# Requirement already satisfied: google-cloud-memcache>=1.7.0 in /home/jtsarmento/.local/lib/python3.10/site-packages (from apache-airflow-providers-google) (1.12.1)
# Requirement already satisfied: google-cloud-build>=3.31.0 in /home/jtsarmento/.local/lib/python3.10/site-packages (from apache-airflow-providers-google) (3.31.1)
# Requirement already satisfied: google-cloud-storage-transfer>=1.4.1 in /home/jtsarmento/.local/lib/python3.10/site-packages (from apache-airflow-providers-google) (1.16.1)
# Requirement already satisfied: google-cloud-spanner!=3.49.0,>=3.11.1 in /home/jtsarmento/.local/lib/python3.10/site-packages (from apache-airflow-providers-google) (3.53.0)
# Requirement already satisfied: google-analytics-admin>=0.9.0 in /home/jtsarmento/.local/lib/python3.10/site-packages (from apache-airflow-providers-google) (0.24.0)
# Requirement already satisfied: google-cloud-run>=0.10.0 in /home/jtsarmento/.local/lib/python3.10/site-packages (from apache-airflow-providers-google) (0.10.17)
# Requirement already satisfied: google-cloud-dlp>=3.12.0 in /home/jtsarmento/.local/lib/python3.10/site-packages (from apache-airflow-providers-google) (3.29.0)
# Requirement already satisfied: dill>=0.2.3 in /home/jtsarmento/.local/lib/python3.10/site-packages (from apache-airflow-providers-google) (0.4.0)
# Requirement already satisfied: google-cloud-dataform>=0.5.0 in /home/jtsarmento/.local/lib/python3.10/site-packages (from apache-airflow-providers-google) (0.6.1)
# Requirement already satisfied: apache-airflow-core==3.0.0 in /home/jtsarmento/.local/lib/python3.10/site-packages (from apache-airflow>=2.9.0->apache-airflow-providers-google) (3.0.0)
# Requirement already satisfied: apache-airflow-task-sdk<1.1.0,>=1.0.0 in /home/jtsarmento/.local/lib/python3.10/site-packages (from apache-airflow>=2.9.0->apache-airflow-providers-google) (1.0.0)
# Requirement already satisfied: lockfile>=0.12.2 in /usr/lib/python3/dist-packages (from apache-airflow-core==3.0.0->apache-airflow>=2.9.0->apache-airflow-providers-google) (0.12.2)
# Requirement already satisfied: universal-pathlib!=0.2.4,>=0.2.2 in /home/jtsarmento/.local/lib/python3.10/site-packages (from apache-airflow-core==3.0.0->apache-airflow>=2.9.0->apache-airflow-providers-google) (0.2.6)
# Requirement already satisfied: jsonschema>=4.19.1 in /home/jtsarmento/.local/lib/python3.10/site-packages (from apache-airflow-core==3.0.0->apache-airflow>=2.9.0->apache-airflow-providers-google) (4.23.0)
# Requirement already satisfied: jinja2>=3.1.5 in /home/jtsarmento/.local/lib/python3.10/site-packages (from apache-airflow-core==3.0.0->apache-airflow>=2.9.0->apache-airflow-providers-google) (3.1.6)
# Requirement already satisfied: requests<3,>=2.31.0 in /home/jtsarmento/.local/lib/python3.10/site-packages (from apache-airflow-core==3.0.0->apache-airflow>=2.9.0->apache-airflow-providers-google) (2.31.0)
# Requirement already satisfied: psutil>=5.8.0 in /home/jtsarmento/.local/lib/python3.10/site-packages (from apache-airflow-core==3.0.0->apache-airflow>=2.9.0->apache-airflow-providers-google) (6.1.1)
# Requirement already satisfied: alembic<2.0,>=1.13.1 in /home/jtsarmento/.local/lib/python3.10/site-packages (from apache-airflow-core==3.0.0->apache-airflow>=2.9.0->apache-airflow-providers-google) (1.15.2)
# Requirement already satisfied: pygments!=2.19.0,>=2.0.1 in /home/jtsarmento/.local/lib/python3.10/site-packages (from apache-airflow-core==3.0.0->apache-airflow>=2.9.0->apache-airflow-providers-google) (2.19.1)
# Requirement already satisfied: itsdangerous>=2.0 in /home/jtsarmento/.local/lib/python3.10/site-packages (from apache-airflow-core==3.0.0->apache-airflow>=2.9.0->apache-airflow-providers-google) (2.2.0)
# Requirement already satisfied: deprecated>=1.2.13 in /home/jtsarmento/.local/lib/python3.10/site-packages (from apache-airflow-core==3.0.0->apache-airflow>=2.9.0->apache-airflow-providers-google) (1.2.18)
# Requirement already satisfied: a2wsgi>=1.10.8 in /home/jtsarmento/.local/lib/python3.10/site-packages (from apache-airflow-core==3.0.0->apache-airflow>=2.9.0->apache-airflow-providers-google) (1.10.8)
# Requirement already satisfied: importlib-metadata>=6.5 in /home/jtsarmento/.local/lib/python3.10/site-packages (from apache-airflow-core==3.0.0->apache-airflow>=2.9.0->apache-airflow-providers-google) (6.11.0)
# Requirement already satisfied: pendulum<4.0,>=2.1.2 in /home/jtsarmento/.local/lib/python3.10/site-packages (from apache-airflow-core==3.0.0->apache-airflow>=2.9.0->apache-airflow-providers-google) (3.1.0)
# Requirement already satisfied: flask>=2.1.1 in /home/jtsarmento/.local/lib/python3.10/site-packages (from apache-airflow-core==3.0.0->apache-airflow>=2.9.0->apache-airflow-providers-google) (3.0.2)
# Requirement already satisfied: apache-airflow-providers-smtp>=2.0.2 in /home/jtsarmento/.local/lib/python3.10/site-packages (from apache-airflow-core==3.0.0->apache-airflow>=2.9.0->apache-airflow-providers-google) (2.0.3)
# Requirement already satisfied: cadwyn>=5.2.1 in /home/jtsarmento/.local/lib/python3.10/site-packages (from apache-airflow-core==3.0.0->apache-airflow>=2.9.0->apache-airflow-providers-google) (5.3.3)
# Requirement already satisfied: opentelemetry-exporter-otlp>=1.24.0 in /home/jtsarmento/.local/lib/python3.10/site-packages (from apache-airflow-core==3.0.0->apache-airflow>=2.9.0->apache-airflow-providers-google) (1.32.1)
# Requirement already satisfied: cryptography>=41.0.0 in /home/jtsarmento/.local/lib/python3.10/site-packages (from apache-airflow-core==3.0.0->apache-airflow>=2.9.0->apache-airflow-providers-google) (44.0.2)
# Requirement already satisfied: termcolor>=3.0.0 in /home/jtsarmento/.local/lib/python3.10/site-packages (from apache-airflow-core==3.0.0->apache-airflow>=2.9.0->apache-airflow-providers-google) (3.0.1)
# Requirement already satisfied: sqlalchemy-jsonfield>=1.0 in /home/jtsarmento/.local/lib/python3.10/site-packages (from apache-airflow-core==3.0.0->apache-airflow>=2.9.0->apache-airflow-providers-google) (1.0.2)
# Requirement already satisfied: rich-argparse>=1.0.0 in /home/jtsarmento/.local/lib/python3.10/site-packages (from apache-airflow-core==3.0.0->apache-airflow>=2.9.0->apache-airflow-providers-google) (1.7.0)
# Requirement already satisfied: attrs!=25.2.0,>=22.1.0 in /home/jtsarmento/.local/lib/python3.10/site-packages (from apache-airflow-core==3.0.0->apache-airflow>=2.9.0->apache-airflow-providers-google) (24.2.0)
# Requirement already satisfied: setproctitle>=1.3.3 in /home/jtsarmento/.local/lib/python3.10/site-packages (from apache-airflow-core==3.0.0->apache-airflow>=2.9.0->apache-airflow-providers-google) (1.3.5)
# Requirement already satisfied: apache-airflow-providers-standard>=0.4.0 in /home/jtsarmento/.local/lib/python3.10/site-packages (from apache-airflow-core==3.0.0->apache-airflow>=2.9.0->apache-airflow-providers-google) (1.0.0)
# Requirement already satisfied: colorlog>=6.8.2 in /home/jtsarmento/.local/lib/python3.10/site-packages (from apache-airflow-core==3.0.0->apache-airflow>=2.9.0->apache-airflow-providers-google) (6.9.0)
# Requirement already satisfied: cron-descriptor>=1.2.24 in /home/jtsarmento/.local/lib/python3.10/site-packages (from apache-airflow-core==3.0.0->apache-airflow>=2.9.0->apache-airflow-providers-google) (1.4.5)
# Requirement already satisfied: gunicorn>=20.1.0 in /home/jtsarmento/.local/lib/python3.10/site-packages (from apache-airflow-core==3.0.0->apache-airflow>=2.9.0->apache-airflow-providers-google) (21.2.0)
# Requirement already satisfied: libcst>=1.1.0 in /home/jtsarmento/.local/lib/python3.10/site-packages (from apache-airflow-core==3.0.0->apache-airflow>=2.9.0->apache-airflow-providers-google) (1.7.0)
# Requirement already satisfied: pathspec>=0.9.0 in /home/jtsarmento/.local/lib/python3.10/site-packages (from apache-airflow-core==3.0.0->apache-airflow>=2.9.0->apache-airflow-providers-google) (0.10.1)
# Requirement already satisfied: opentelemetry-api>=1.24.0 in /home/jtsarmento/.local/lib/python3.10/site-packages (from apache-airflow-core==3.0.0->apache-airflow>=2.9.0->apache-airflow-providers-google) (1.32.1)
# Requirement already satisfied: uuid6>=2024.7.10 in /home/jtsarmento/.local/lib/python3.10/site-packages (from apache-airflow-core==3.0.0->apache-airflow>=2.9.0->apache-airflow-providers-google) (2024.7.10)
# Requirement already satisfied: apache-airflow-providers-common-io>=1.5.3 in /home/jtsarmento/.local/lib/python3.10/site-packages (from apache-airflow-core==3.0.0->apache-airflow>=2.9.0->apache-airflow-providers-google) (1.5.4)
# Requirement already satisfied: methodtools>=0.4.7 in /home/jtsarmento/.local/lib/python3.10/site-packages (from apache-airflow-core==3.0.0->apache-airflow>=2.9.0->apache-airflow-providers-google) (0.4.7)
# Requirement already satisfied: fastapi[standard]!=0.115.10,>=0.115.0 in /home/jtsarmento/.local/lib/python3.10/site-packages (from apache-airflow-core==3.0.0->apache-airflow>=2.9.0->apache-airflow-providers-google) (0.115.12)
# Requirement already satisfied: croniter>=2.0.2 in /home/jtsarmento/.local/lib/python3.10/site-packages (from apache-airflow-core==3.0.0->apache-airflow>=2.9.0->apache-airflow-providers-google) (6.0.0)
# Requirement already satisfied: aiosqlite>=0.20.0 in /home/jtsarmento/.local/lib/python3.10/site-packages (from apache-airflow-core==3.0.0->apache-airflow>=2.9.0->apache-airflow-providers-google) (0.21.0)
# Requirement already satisfied: sqlalchemy-utils>=0.41.2 in /home/jtsarmento/.local/lib/python3.10/site-packages (from apache-airflow-core==3.0.0->apache-airflow>=2.9.0->apache-airflow-providers-google) (0.41.2)
# Requirement already satisfied: sqlalchemy<2.0,>=1.4.49 in /home/jtsarmento/.local/lib/python3.10/site-packages (from apache-airflow-core==3.0.0->apache-airflow>=2.9.0->apache-airflow-providers-google) (1.4.54)
# Requirement already satisfied: svcs>=25.1.0 in /home/jtsarmento/.local/lib/python3.10/site-packages (from apache-airflow-core==3.0.0->apache-airflow>=2.9.0->apache-airflow-providers-google) (25.1.0)
# Requirement already satisfied: tabulate>=0.9.0 in /home/jtsarmento/.local/lib/python3.10/site-packages (from apache-airflow-core==3.0.0->apache-airflow>=2.9.0->apache-airflow-providers-google) (0.9.0)
# Requirement already satisfied: lazy-object-proxy>=1.2.0 in /home/jtsarmento/.local/lib/python3.10/site-packages (from apache-airflow-core==3.0.0->apache-airflow>=2.9.0->apache-airflow-providers-google) (1.11.0)
# Requirement already satisfied: pyjwt>=2.10.0 in /home/jtsarmento/.local/lib/python3.10/site-packages (from apache-airflow-core==3.0.0->apache-airflow>=2.9.0->apache-airflow-providers-google) (2.10.1)
# Requirement already satisfied: pluggy>=1.5.0 in /home/jtsarmento/.local/lib/python3.10/site-packages (from apache-airflow-core==3.0.0->apache-airflow>=2.9.0->apache-airflow-providers-google) (1.5.0)
# Requirement already satisfied: rich>=13.6.0 in /home/jtsarmento/.local/lib/python3.10/site-packages (from apache-airflow-core==3.0.0->apache-airflow>=2.9.0->apache-airflow-providers-google) (14.0.0)
# Requirement already satisfied: pydantic>=2.11.0 in /home/jtsarmento/.local/lib/python3.10/site-packages (from apache-airflow-core==3.0.0->apache-airflow>=2.9.0->apache-airflow-providers-google) (2.11.3)
# Requirement already satisfied: argcomplete>=1.10 in /home/jtsarmento/.local/lib/python3.10/site-packages (from apache-airflow-core==3.0.0->apache-airflow>=2.9.0->apache-airflow-providers-google) (3.6.2)
# Requirement already satisfied: linkify-it-py>=2.0.0 in /home/jtsarmento/.local/lib/python3.10/site-packages (from apache-airflow-core==3.0.0->apache-airflow>=2.9.0->apache-airflow-providers-google) (2.0.3)
# Requirement already satisfied: gitpython>=3.1.40 in /home/jtsarmento/.local/lib/python3.10/site-packages (from apache-airflow-core==3.0.0->apache-airflow>=2.9.0->apache-airflow-providers-google) (3.1.44)
# Requirement already satisfied: python-daemon>=3.0.0 in /home/jtsarmento/.local/lib/python3.10/site-packages (from apache-airflow-core==3.0.0->apache-airflow>=2.9.0->apache-airflow-providers-google) (3.1.2)
# Requirement already satisfied: sqlparse>=0.5.1 in /home/jtsarmento/.local/lib/python3.10/site-packages (from apache-airflow-providers-common-sql>=1.20.0->apache-airflow-providers-google) (0.5.1)
# Requirement already satisfied: more-itertools>=9.0.0 in /home/jtsarmento/.local/lib/python3.10/site-packages (from apache-airflow-providers-common-sql>=1.20.0->apache-airflow-providers-google) (10.7.0)
# Requirement already satisfied: typing-extensions>=4 in /home/jtsarmento/.local/lib/python3.10/site-packages (from asgiref>=3.5.2->apache-airflow-providers-google) (4.12.2)
# Requirement already satisfied: chardet<6.0,>=2.0 in /usr/lib/python3/dist-packages (from gcloud-aio-auth>=5.2.0->apache-airflow-providers-google) (4.0.0)
# Requirement already satisfied: backoff<3.0.0,>=1.0.0 in /home/jtsarmento/.local/lib/python3.10/site-packages (from gcloud-aio-auth>=5.2.0->apache-airflow-providers-google) (2.2.1)
# Requirement already satisfied: aiohttp<4.0.0,>=3.9.0 in /home/jtsarmento/.local/lib/python3.10/site-packages (from gcloud-aio-auth>=5.2.0->apache-airflow-providers-google) (3.11.13)
# Requirement already satisfied: aiofiles<25.0.0,>=0.6.0 in /home/jtsarmento/.local/lib/python3.10/site-packages (from gcloud-aio-storage>=9.0.0->apache-airflow-providers-google) (24.1.0)
# Requirement already satisfied: fsspec==2025.3.2 in /home/jtsarmento/.local/lib/python3.10/site-packages (from gcsfs>=2023.10.0->apache-airflow-providers-google) (2025.3.2)
# Requirement already satisfied: decorator>4.1.2 in /home/jtsarmento/.local/lib/python3.10/site-packages (from gcsfs>=2023.10.0->apache-airflow-providers-google) (5.1.1)
# Requirement already satisfied: googleapis-common-protos<2.0.0,>=1.56.3 in /home/jtsarmento/.local/lib/python3.10/site-packages (from google-ads>=26.0.0->apache-airflow-providers-google) (1.66.0)
# Requirement already satisfied: PyYAML<7.0,>=5.1 in /home/jtsarmento/.local/lib/python3.10/site-packages (from google-ads>=26.0.0->apache-airflow-providers-google) (6.0.2)
# Requirement already satisfied: grpcio-status<2.0.0,>=1.59.0 in /home/jtsarmento/.local/lib/python3.10/site-packages (from google-ads>=26.0.0->apache-airflow-providers-google) (1.71.0)
# Requirement already satisfied: grpcio<2.0.0,>=1.59.0 in /home/jtsarmento/.local/lib/python3.10/site-packages (from google-ads>=26.0.0->apache-airflow-providers-google) (1.71.0)
# Requirement already satisfied: protobuf<7.0.0,>=4.25.0 in /home/jtsarmento/.local/lib/python3.10/site-packages (from google-ads>=26.0.0->apache-airflow-providers-google) (5.29.4)
# Requirement already satisfied: uritemplate<5,>=3.0.1 in /home/jtsarmento/.local/lib/python3.10/site-packages (from google-api-python-client>=2.0.2->apache-airflow-providers-google) (4.1.1)
# Requirement already satisfied: httplib2<1.dev0,>=0.19.0 in /usr/lib/python3/dist-packages (from google-api-python-client>=2.0.2->apache-airflow-providers-google) (0.20.2)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /home/jtsarmento/.local/lib/python3.10/site-packages (from google-auth-oauthlib>=0.7.0->pandas-gbq) (1.3.1)
# Requirement already satisfied: docstring-parser<1 in /home/jtsarmento/.local/lib/python3.10/site-packages (from google-cloud-aiplatform[evaluation]>=1.73.0->apache-airflow-providers-google) (0.16)
# Requirement already satisfied: shapely<3.0.0 in /home/jtsarmento/.local/lib/python3.10/site-packages (from google-cloud-aiplatform[evaluation]>=1.73.0->apache-airflow-providers-google) (2.1.0)
# Requirement already satisfied: google-cloud-resource-manager<3.0.0,>=1.3.3 in /home/jtsarmento/.local/lib/python3.10/site-packages (from google-cloud-aiplatform[evaluation]>=1.73.0->apache-airflow-providers-google) (1.14.2)
# Requirement already satisfied: tqdm>=4.23.0 in /home/jtsarmento/.local/lib/python3.10/site-packages (from google-cloud-aiplatform[evaluation]>=1.73.0->apache-airflow-providers-google) (4.67.1)
# Requirement already satisfied: ruamel.yaml in /home/jtsarmento/.local/lib/python3.10/site-packages (from google-cloud-aiplatform[evaluation]>=1.73.0->apache-airflow-providers-google) (0.18.10)
# Collecting scikit-learn<1.6.0
#   Using cached scikit_learn-1.5.2-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (13.3 MB)
# Requirement already satisfied: grpc-google-iam-v1<1.0.0,>=0.14.0 in /home/jtsarmento/.local/lib/python3.10/site-packages (from google-cloud-alloydb>=0.4.0->apache-airflow-providers-google) (0.14.2)
# Requirement already satisfied: google-resumable-media<3.0.0,>=2.0.0 in /home/jtsarmento/.local/lib/python3.10/site-packages (from google-cloud-bigquery<4.0.0dev,>=3.4.2->pandas-gbq) (2.7.2)
# Requirement already satisfied: google-cloud-core<3.0.0,>=2.4.1 in /home/jtsarmento/.local/lib/python3.10/site-packages (from google-cloud-bigquery<4.0.0dev,>=3.4.2->pandas-gbq) (2.4.3)
# Requirement already satisfied: google-crc32c<2.0.0dev,>=1.5.0 in /home/jtsarmento/.local/lib/python3.10/site-packages (from google-cloud-bigtable>=2.17.0->apache-airflow-providers-google) (1.7.1)
# Requirement already satisfied: google-cloud-appengine-logging<2.0.0,>=0.1.3 in /home/jtsarmento/.local/lib/python3.10/site-packages (from google-cloud-logging>=3.5.0->apache-airflow-providers-google) (1.6.1)
# Requirement already satisfied: google-cloud-audit-log<1.0.0,>=0.3.1 in /home/jtsarmento/.local/lib/python3.10/site-packages (from google-cloud-logging>=3.5.0->apache-airflow-providers-google) (0.3.2)
# Requirement already satisfied: opentelemetry-sdk>=1.27.0 in /home/jtsarmento/.local/lib/python3.10/site-packages (from google-cloud-pubsub>=2.21.3->apache-airflow-providers-google) (1.32.1)
# Requirement already satisfied: grpc-interceptor>=0.15.4 in /home/jtsarmento/.local/lib/python3.10/site-packages (from google-cloud-spanner!=3.49.0,>=3.11.1->apache-airflow-providers-google) (0.15.4)
# Requirement already satisfied: httpcore==1.* in /home/jtsarmento/.local/lib/python3.10/site-packages (from httpx>=0.25.0->apache-airflow-providers-google) (1.0.7)
# Requirement already satisfied: anyio in /home/jtsarmento/.local/lib/python3.10/site-packages (from httpx>=0.25.0->apache-airflow-providers-google) (4.7.0)
# Requirement already satisfied: certifi in /usr/lib/python3/dist-packages (from httpx>=0.25.0->apache-airflow-providers-google) (2020.6.20)
# Requirement already satisfied: idna in /usr/lib/python3/dist-packages (from httpx>=0.25.0->apache-airflow-providers-google) (3.3)
# Requirement already satisfied: h11<0.15,>=0.13 in /home/jtsarmento/.local/lib/python3.10/site-packages (from httpcore==1.*->httpx>=0.25.0->apache-airflow-providers-google) (0.14.0)
# Requirement already satisfied: cattrs>=1.3 in /home/jtsarmento/.local/lib/python3.10/site-packages (from looker-sdk!=24.18.0,>=22.4.0->apache-airflow-providers-google) (24.1.3)
# Requirement already satisfied: pytz>=2020.1 in /home/jtsarmento/.local/lib/python3.10/site-packages (from pandas>=1.1.4->pandas-gbq) (2025.2)
# Requirement already satisfied: tzdata>=2022.1 in /home/jtsarmento/.local/lib/python3.10/site-packages (from pandas>=1.1.4->pandas-gbq) (2024.2)

# %%
import numpy as np, pandas as pd, scipy, sklearn
from sklearn.model_selection import train_test_split
print(np.__version__, pd.__version__, scipy.__version__, sklearn.__version__)
# Out:
# 2.2.5 2.2.3 1.15.2 1.6.1

# %% [markdown]
# ## Default Arguments and Constants

# %%
PROJECT_ID = 'terraform-457118'
DATASET_ID = 'stock_market_data'
LOCATION = 'US'
TABLE_ID = 'stock_data_raw'
SERVICE_ACCOUNT_PATH = '/home/jtsarmento/Projects/airflow-dbt-demo/keys/service-account.json'
HISTORY_DAYS = '365'

# Define dataset paths
RAW_TABLE = f"`{PROJECT_ID}.{DATASET_ID}.{TABLE_ID}`"
METRICS_TABLE = f"{DATASET_ID}.model_metrics"
PREDICTIONS_TABLE = f"{DATASET_ID}.price_predictions"
MARTS_DATASET = f"{DATASET_ID}_marts"
STAGING_DATASET = f"{DATASET_ID}_staging"

# %%
from google.oauth2 import service_account
import pandas_gbq

creds = service_account.Credentials.from_service_account_file(
    SERVICE_ACCOUNT_PATH,
    scopes=["https://www.googleapis.com/auth/bigquery"],
)

query = f"""
SELECT 
  symbol, date, close,
  LAG(close,1)  OVER(PARTITION BY symbol ORDER BY date) AS prev_close_1,
  volume,
  LAG(volume,1) OVER(PARTITION BY symbol ORDER BY date) AS prev_volume_1
FROM `{PROJECT_ID}.{DATASET_ID}.{TABLE_ID}`
WHERE date >= DATE_SUB(CURRENT_DATE(), INTERVAL {HISTORY_DAYS} DAY)
ORDER BY symbol, date
"""

df_raw = pandas_gbq.read_gbq(query, project_id=PROJECT_ID, credentials=creds)
df_raw.head(), df_raw.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1757 entries, 0 to 1756
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   symbol         1757 non-null   object
#  1   date           1757 non-null   dbdate
#  2   close          1757 non-null   float64
#  3   prev_close_1   1750 non-null   float64
#  4   volume         1757 non-null   Int64
#  5   prev_volume_1  1750 non-null   Int64
# dtypes: Int64(2), dbdate(1), float64(2), object(1)
# memory usage: 85.9+ KB
# (  symbol        date       close  prev_close_1    volume  prev_volume_1
#  0   AAPL  2024-04-25  169.091568           NaN  50558300           <NA>
#  1   AAPL  2024-04-26  168.504349    169.091568  44838400       50558300
#  2   AAPL  2024-04-29  172.684601    168.504349  68169400       44838400
#  3   AAPL  2024-04-30  169.529510    172.684601  65934800       68169400
#  4   AAPL  2024-05-01  168.504349    169.529510  50383100       65934800,
#  None)

# %% [markdown]
# ## prepare_features Task

# %%
query = f"""
SELECT 
    symbol,
    date,
    close,
    LAG(close, 1) OVER(PARTITION BY symbol ORDER BY date) as prev_close_1,
    LAG(close, 2) OVER(PARTITION BY symbol ORDER BY date) as prev_close_2,
    LAG(close, 3) OVER(PARTITION BY symbol ORDER BY date) as prev_close_3,
    LAG(close, 4) OVER(PARTITION BY symbol ORDER BY date) as prev_close_4,
    LAG(close, 5) OVER(PARTITION BY symbol ORDER BY date) as prev_close_5,
    volume,
    LAG(volume, 1) OVER(PARTITION BY symbol ORDER BY date) as prev_volume_1
FROM 
    {RAW_TABLE}
WHERE 
    date >= DATE_SUB(CURRENT_DATE(), INTERVAL {HISTORY_DAYS} DAY)
ORDER BY 
    symbol, date
"""
from google.oauth2 import service_account
import pandas_gbq

credentials = service_account.Credentials.from_service_account_file(
    SERVICE_ACCOUNT_PATH,
    scopes=["https://www.googleapis.com/auth/bigquery"]
)

df = pandas_gbq.read_gbq(query, project_id=PROJECT_ID, credentials=credentials)
df = df.dropna()
df['price_change'] = df['close'] - df['prev_close_1']
df['price_change_pct'] = df['price_change'] / df['prev_close_1']
df['volume_change_pct'] = (df['volume'] - df['prev_volume_1']) / df['prev_volume_1']
# df.to_csv('/downloads/prepared_features.csv', index=False)
print(f"Prepared features for {len(df)} rows across {df['symbol'].nunique()} symbols")
print(df.head())
# Out:
# Prepared features for 1722 rows across 7 symbols
#   symbol        date       close  prev_close_1  prev_close_2  prev_close_3  \
# 5   AAPL  2024-05-02  172.216827    168.504349    169.529510    172.684601
# 6   AAPL  2024-05-03  182.518188    172.216827    168.504349    169.529510
# 7   AAPL  2024-05-06  180.856049    182.518188    172.216827    168.504349
# 8   AAPL  2024-05-07  181.542786    180.856049    182.518188    172.216827
# 9   AAPL  2024-05-08  181.881195    181.542786    180.856049    182.518188
#
#    prev_close_4  prev_close_5     volume  prev_volume_1  price_change  \
# 5    168.504349    169.091568   94214900       50383100      3.712479
# 6    172.684601    168.504349  163224100       94214900     10.301361
# 7    169.529510    172.684601   78569700      163224100     -1.662140
# 8    168.504349    169.529510   77305800       78569700      0.686737
# 9    172.216827    168.504349   45057100       77305800      0.338409
#
#    price_change_pct  volume_change_pct
# 5          0.022032            0.86997
# 6          0.059816           0.732466
# 7         -0.009107          -0.518639
# 8          0.003797          -0.016086
# 9          0.001864          -0.417158

# %% [markdown]
# ## train_model Task

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_squared_error, r2_score
import joblib


# Build a records list including date, features, actual, predicted, error
records = []
features = [
    'prev_close_1','prev_close_2','prev_close_3',
    'prev_close_4','prev_close_5','prev_volume_1',
    'price_change','price_change_pct','volume_change_pct'
]

for symbol in df['symbol'].unique():
    # Prepare symbol-specific DataFrame with date
    symbol_df = df[df['symbol'] == symbol].copy()
    data = symbol_df[['date'] + features + ['close']]

    # Split
    train, test = train_test_split(data, test_size=0.2, random_state=42)

    # Train
    model = RandomForestRegressor(n_estimators=100, random_state=42)
    model.fit(train[features], train['close'])

    # Predict
    preds = model.predict(test[features])
    test = test.reset_index(drop=True)

    # Collect results
    for i, row in test.iterrows():
        actual = row['close']
        pred = preds[i]
        rec = {
            'symbol': symbol,
            'date': row['date'],
            'actual': actual,
            'predicted': pred,
            'error': pred - actual
        }
        # Add feature columns
        for feat in features:
            rec[feat] = row[feat]
        records.append(rec)

# Create DataFrame and display
results_df = pd.DataFrame(records)
# …after collecting records…
results_df = pd.DataFrame(records)

# Sort by date ascending (and symbol if you want symbol groups)
results_df = results_df.sort_values(by=['symbol','date'], ascending=[True, True]).reset_index(drop=True)


print(results_df.head())
# Out:
#   symbol        date      actual   predicted     error  prev_close_1  \
# 0   AAPL  2024-05-10  182.436844  185.253645  2.816801    183.702606
# 1   AAPL  2024-05-15  189.084503  187.080103 -2.004401    186.802170
# 2   AAPL  2024-05-16  189.204102  188.241727 -0.962375    189.084503
# 3   AAPL  2024-05-23  186.254013  191.676177  5.422164    190.260544
# 4   AAPL  2024-05-24  189.343628  191.382126  2.038499    186.254013
#
#    prev_close_2  prev_close_3  prev_close_4  prev_close_5  prev_volume_1  \
# 0    181.881195    181.542786    180.856049    182.518188       48983000
# 1    185.656006    182.436844    183.702606    181.881195       52393600
# 2    186.802170    185.656006    182.436844    183.702606       70400000
# 3    191.705704    190.400085    189.233994    189.204102       34648500
# 4    190.260544    191.705704    190.400085    189.233994       51005900
#
#    price_change  price_change_pct  volume_change_pct
# 0     -1.265762         -0.006890           0.036268
# 1      2.282333          0.012218           0.343676
# 2      0.119598          0.000633          -0.249358
# 3     -4.006531         -0.021058           0.472095
# 4      3.089615          0.016588          -0.288423

# %%
import numpy as np
from sklearn.metrics import r2_score

# … after you’ve built and sorted results_df …

# 1) Compute summary metrics per symbol
summary = results_df.groupby('symbol').apply(
    lambda grp: pd.Series({
        'count':        len(grp),
        'MAE':          grp['error'].abs().mean(),
        'MSE':          (grp['error']**2).mean(),
        'RMSE':         np.sqrt((grp['error']**2).mean()),
        'Mean Error':   grp['error'].mean(),
        'R2 Score':     r2_score(grp['actual'], grp['predicted'])
    })
).reset_index()

# 2) Rank by RMSE (lowest is best)
summary = summary.sort_values('RMSE').reset_index(drop=True)

# 3) Show the ranking
print("Performance ranking by RMSE:")
print(summary)

# Optional: merge back into results_df if you want symbol-level stats on every row
results_df = results_df.merge(summary[['symbol','MAE','RMSE','R2 Score']], on='symbol', how='left')
# Out:
# Performance ranking by RMSE:
#   symbol  count       MAE         MSE       RMSE  Mean Error  R2 Score
# 0     EU   50.0  0.055768    0.005731   0.075706    0.011212  0.995626
# 1  GOOGL   50.0  1.246353    3.434206   1.853161    0.157977  0.981409
# 2   CELH   50.0  1.137653    3.974211   1.993542    0.106089  0.991345
# 3   AMZN   50.0  1.673389    8.040863   2.835642    0.447877  0.980400
# 4   MSFT   50.0  2.533694   14.490864   3.806687    0.536989  0.975373
# 5   AAPL   50.0  2.440495   15.263162   3.906810    0.682667  0.955681
# 6   META   50.0  8.337671  129.002907  11.357945   -0.815428  0.972362
# /tmp/ipykernel_2013867/570016772.py:7: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   summary = results_df.groupby('symbol').apply(

# %%
from datetime import timedelta
import holidays

# (Re-define or copy in your trading‐day logic)
def is_trading_day(d):
    if d.weekday() >= 5:  # Saturday=5, Sunday=6
        return False
    us_hols = holidays.US(years=d.year)
    market_hols = {
        "New Year's Day", "Martin Luther King Jr. Day", "Presidents Day",
        "Good Friday", "Memorial Day", "Juneteenth National Independence Day",
        "Independence Day", "Labor Day", "Thanksgiving", "Christmas Day"
    }
    name = us_hols.get(d)
    return not (name and any(h in name for h in market_hols))

def next_trading_day(d):
    nd = d + timedelta(days=1)
    while not is_trading_day(nd):
        nd += timedelta(days=1)
    return nd

# Build predictions
next_preds = []
for symbol, model in models.items():
    sym_df = df[df['symbol']==symbol].sort_values('date')
    last_row = sym_df.iloc[-1]
    
    # feature vector for the most recent date
    X_new = last_row[features].values.reshape(1, -1)
    pred_price = model.predict(X_new)[0]
    
    # compute next trading date
    last_date = pd.to_datetime(last_row['date']).date()
    next_date = next_trading_day(last_date)
    
    next_preds.append({
        'symbol': symbol,
        'last_date':  last_date,
        'next_date':  next_date,
        'predicted_close': pred_price,
        'last_close':      last_row['close'],
        'predicted_change': pred_price - last_row['close'],
        'predicted_pct':   (pred_price - last_row['close'])/last_row['close']*100
    })

# Show as DataFrame
next_pred_df = pd.DataFrame(next_preds)
next_pred_df
# Out:
# /home/jtsarmento/.local/lib/python3.10/site-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# /home/jtsarmento/.local/lib/python3.10/site-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# /home/jtsarmento/.local/lib/python3.10/site-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# /home/jtsarmento/.local/lib/python3.10/site-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# /home/jtsarmento/.local/lib/python3.10/site-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# /home/jtsarmento/.local/lib/python3.10/site-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# /home/jtsarmento/.local/lib/python3.10/site-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
#   symbol   last_date   next_date  predicted_close  last_close  \
# 0   AAPL  2025-04-25  2025-04-28       207.313665  208.080002
# 1   AMZN  2025-04-25  2025-04-28       188.454303  188.865005
# 2   CELH  2025-04-25  2025-04-28        36.611560   36.400101
# 3     EU  2025-04-25  2025-04-28         1.525300    1.570000
# 4  GOOGL  2025-04-25  2025-04-28       160.668885  161.660004
# 5   META  2025-04-25  2025-04-28       540.545451  546.914978
# 6   MSFT  2025-04-25  2025-04-28       388.711951  390.095001
#
#    predicted_change  predicted_pct
# 0         -0.766337      -0.368290
# 1         -0.410702      -0.217458
# 2          0.211460       0.580932
# 3         -0.044700      -2.847135
# 4         -0.991118      -0.613088
# 5         -6.369527      -1.164628
# 6         -1.383050      -0.354542
